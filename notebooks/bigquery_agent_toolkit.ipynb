# %% [markdown]
# # BigQuery Agent Toolkit Demo

# %%
import setup

import os
import pprint
import json
import google.auth
from google.cloud import bigquery
from langchain.chat_models import ChatOpenAI
from google.oauth2 import service_account

from chartgpt.agents.agent_toolkits import create_bigquery_agent
from chartgpt.agents.agent_toolkits.bigquery.utils import get_dataset_ids, get_table_ids, get_tables_summary

pp = pprint.PrettyPrinter(indent=4)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[1], line 11
#       8 from langchain.chat_models import ChatOpenAI
#       9 from google.oauth2 import service_account
# ---> 11 from chartgpt.agents.agent_toolkits import create_bigquery_agent
#      12 from chartgpt.agents.agent_toolkits.bigquery.utils import get_dataset_ids, get_table_ids, get_tables_summary
#      14 pp = pprint.PrettyPrinter(indent=4)
#
# File ~/workspace/CADLabs/nftfi-agi-streamlit/chartgpt/__init__.py:1
# ----> 1 from chartgpt.app import get_agent
#       3 __all__ = [
#       4     "get_agent",
#       5 ]
#
# File ~/workspace/CADLabs/nftfi-agi-streamlit/chartgpt/app.py:24
#      18 scopes = [
#      19     "https://www.googleapis.com/auth/drive",
#      20     "https://www.googleapis.com/auth/bigquery",
#      21 ]
#      23 if os.environ.get("GCP_SERVICE_ACCOUNT", False):
# ---> 24     credentials = service_account.Credentials.from_service_account_info(json.loads(os.environ["GCP_SERVICE_ACCOUNT"], strict=False)).with_scopes(scopes)
#      25     client = bigquery.Client(credentials=credentials)
#      26 else:
#      27     # If deployed using App Engine, use default App Engine credentials
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     357 if parse_constant is not None:
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
credentials = service_account.Credentials.from_service_account_info(json.loads(os.environ["GCP_SERVICE_ACCOUNT"], strict=False))
client = bigquery.Client(credentials=credentials)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 credentials = service_account.Credentials.from_service_account_info(json.loads(os.environ["GCP_SERVICE_ACCOUNT"], strict=False))
#       2 client = bigquery.Client(credentials=credentials)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     357 if parse_constant is not None:
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File /opt/homebrew/Cellar/python@3.11/3.11.3/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)

# %%
get_dataset_ids(client=client)

# %%
get_table_ids(client=client)

# %%
print(json.dumps(get_tables_summary(client=client), sort_keys=True, indent=4))

# %%
agent = create_bigquery_agent(ChatOpenAI(temperature=0), bigquery_client=client, verbose=True)

# %%
agent.run("Plot the total loan volume per day using Plotly")

# %%
agent.run("Plot the loan principal amount of the top 5 asset classes by volume over time")

# %%
agent.run("Plot the borrow volume over time for nftfi, benddao, arcade, jpegd")

# %%
agent.run("Plot the weekly distribution of unique users over time")

# %%
agent.run("On what date x2y2 had the highest number of users?")

# %%
agent.run("Plot the weekly NFT finance market share by unique users")

# %%
agent.run("Plot the weekly NFT finance market share percentage by unique users")

# %%
agent.run("Using the dune_dataset dataset, plot users and volume for each platform on different y axes")

# %%
agent.run("Using the dataset 'dune_dataset', plot the number of users and volume on different y axes")

# %%
agent.run("Plot the number of NFT liquidations and repayment volume on different y axes for BendDAO")
