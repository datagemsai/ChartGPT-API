# %%
import pandas as pd
import numpy as np
import re
def format_bigquery_column_names(nftfi):
    # Remove special charachters
    nftfi.columns = [re.sub(r'[^a-zA-Z0-9\s]+', '', column) for column in nftfi.columns]
    # Remove spaces at beginning and end
    nftfi.columns = nftfi.columns.str.strip()
    # Replace spaces with underscore
    nftfi.columns = nftfi.columns.str.replace(' ', '_')
    # Define a function to convert camel-case to kebab-case
    def camel_to_kebab(s):
        # Replace consecutive capital letters with a single lowercase letter
        s = re.sub(r'(?<=[a-z])(?=[A-Z])', '_', s)
        # Convert remaining camel-case string to kebab-case
        s = re.sub(r'(?<!^)(?<!_)(?=[A-Z])(?![A-Z])', '_', s).lower()
        return s
    # Apply the function to all column names
    nftfi.columns = nftfi.columns.map(camel_to_kebab)
    return nftfi

# %% [markdown]
# ## Load tables

# %%
try: 
    mq = pd.read_csv('mq.csv')
except FileNotFoundError:
    mq = pd.read_csv('analysis/mq.csv')
nftfi = pd.read_csv('../analytics_bot_langchain/data/nftfi/loans_with_transaction_hash.csv')
nftfi = format_bigquery_column_names(nftfi)
nftfi = nftfi.rename(columns={'loan_id': 'loan_no', 'loan_date': 'date'})

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
print('MQ')
display(mq.head(2))
print('\n--------------------------------------------------------------------')
print('\n\nNFTfi')
display(nftfi.head(2))
# Out:
# MQ
#                                     transaction_hash  \
# 0  0x933ff7d3b9d60593c97a5c9ab28205e54f019259defd...
# 1  0xd1b9fbddbcaaaea8fa8b19cfa53c5e9093993f0d51c0...
#
#                   block_timestamp  loan_id  \
# 0  2022-02-26 09:26:37.000000 UTC    -4882
# 1  2022-04-19 22:33:16.000000 UTC      733
#
#                                    to_address  \
# 0  0x676f3d2c9f5776e09d23986adc6684fb41e9000e
# 1  0x676f3d2c9f5776e09d23986adc6684fb41e9000e
#
#                                  from_address  principal_amount  \
# 0  0x0aff497bd016000185b1c8302fa98a88ff4a4178               0.8
# 1  0x2c35b3d207f745ad5b17d88328286c49a0ce4d4f               1.4
#
#    repayment_amount                               erc20_address erc20_name  \
# 0          0.826624  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 1          1.413425  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
#
#                          due_date  duration_in_days       apr token_id  \
# 0  2022-03-28 09:26:37.000000 UTC              30.0  0.405000     1378
# 1  2022-04-26 22:33:16.000000 UTC               7.0  0.500013     1378
#
#                            collection_address protocol  amt_in_usd  roll_over  \
# 0  0x026224a2940bfe258d0dbe947919b62fe321f042    nftfi  2205.66016      False
# 1  0x026224a2940bfe258d0dbe947919b62fe321f042    nftfi  4339.42642      False
#
#    block_number p2p_p2pool
# 0      14280871        p2p
# 1      14618284        p2p
# --------------------------------------------------------------------
#
#
# NFTfi
#            loan_no  id  loan_contract  status  \
# 0  v1.loan.fixed-0   0  v1.loan.fixed  repaid
# 1  v1.loan.fixed-1   1  v1.loan.fixed  repaid
#
#                                      borrower  \
# 0  0xc35A5FEc6BE6957899E15559Be252Db882220b37
# 1  0xc35A5FEc6BE6957899E15559Be252Db882220b37
#
#                                        lender loan_principal_amount  \
# 0  0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe     30000000000000000
# 1  0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe      3000000000000000
#
#   maximum_repayment_amount  loan_duration_d    loan_apr  loan_start_time  \
# 0        35000000000000000                7  869.047619       1589580384
# 1         3100000000000000                7  173.809524       1589623507
#
#                        date                      loan_erc20denomination  \
# 0  2020-05-15T22:06:24.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 1  2020-05-16T10:05:07.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
#
#    block_num                                   transaction_hash    gas_price  \
# 0   10073259  0x7c7675a6613ddaded0b187314c2edd3ad3c5428a7a14...  17782723583
# 1   10076484  0x937a5320404c0c835f2739c84b229ef837a9f0b0ef92...  19755020080
#
#    gas_limit  gas_used  cumulative_gas_used  effective_gas_price  repaid  \
# 0    1000000    436882              3212704          17782723583     1.0
# 1     500000    441106              9710213          19755020080     1.0
#
#    liquidated          loan_repaid_time repaid_amount_paid_to_lender  \
# 0         NaN  2020-05-16T09:25:02.000Z            34750000000000000
# 1         NaN  2020-05-16T11:50:26.000Z             3095000000000000
#
#                              repaid_transaction_hash  repaid_gas_price  \
# 0  0x3e24b9cd4c0208acc25259d4fcbddf75b48a554d6814...      1.900000e+10
# 1  0x59d1c26160b7bdde716b380364b506e056d852ac1b36...      1.697449e+10
#
#    repaid_gas_limit  repaid_gas_used  repaid_cumulative_gas_used  \
# 0          500000.0         120497.0                   9549420.0
# 1          500000.0         122603.0                   9470068.0
#
#    repaid_effective_gas_price repaid_admin_fee loan_liquidation_date  \
# 0                1.900000e+10  250000000000000                   NaN
# 1                1.697449e+10    5000000000000                   NaN
#
#   liquidated_transaction_hash  liquidated_gas_price  liquidated_gas_limit  \
# 0                         NaN                   NaN                   NaN
# 1                         NaN                   NaN                   NaN
#
#    liquidated_gas_used  liquidated_cumulative_gas_used  \
# 0                  NaN                             NaN
# 1                  NaN                             NaN
#
#    liquidated_effective_gas_price
# 0                             NaN
# 1                             NaN

# %%
mq['loan_id'].head(2)
# Out:
# 0   -4882
# 1     733
# Name: loan_id, dtype: int64

# %% [markdown]
# ### Clean data

# %%
# clean loan IDs to try and compare them
mq['loan_id_cleaned'] = mq['loan_id'].astype(str).str.replace('-','')
nftfi['loan_no_cleaned'] = nftfi['loan_no'].str.split('-').apply(lambda x: x[-1])
nftfi
# Out:
#                               loan_no     id             loan_contract  \
# 0                     v1.loan.fixed-0      0             v1.loan.fixed
# 1                     v1.loan.fixed-1      1             v1.loan.fixed
# 2                     v1.loan.fixed-2      2             v1.loan.fixed
# 3                     v1.loan.fixed-3      3             v1.loan.fixed
# 4                     v1.loan.fixed-4      4             v1.loan.fixed
# ...                               ...    ...                       ...
# 40750           v2-1.loan.fixed-33827  33827           v2-1.loan.fixed
# 40751  v2.loan.fixed.collection-33811  33811  v2.loan.fixed.collection
# 40752  v2.loan.fixed.collection-33814  33814  v2.loan.fixed.collection
# 40753  v2.loan.fixed.collection-33817  33817  v2.loan.fixed.collection
# 40754  v2.loan.fixed.collection-33826  33826  v2.loan.fixed.collection
#
#        status                                    borrower  \
# 0      repaid  0xc35A5FEc6BE6957899E15559Be252Db882220b37
# 1      repaid  0xc35A5FEc6BE6957899E15559Be252Db882220b37
# 2      repaid  0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe
# 3      repaid  0xc35A5FEc6BE6957899E15559Be252Db882220b37
# 4      repaid  0xc35A5FEc6BE6957899E15559Be252Db882220b37
# ...       ...                                         ...
# 40750     NaN  0x887b86B6B6957F7bbeA88B8CEfD392f39236A88C
# 40751     NaN  0xeE8Cd54223A93DD9B3B2C4701cb1Be5f6886C366
# 40752     NaN  0xCffC336E6D019C1aF58257A0b10bf2146a3f42A4
# 40753     NaN  0xCffC336E6D019C1aF58257A0b10bf2146a3f42A4
# 40754     NaN  0x739dEB8B1232BF13687c0607dd3035E983b3f56F
#
#                                            lender    loan_principal_amount  \
# 0      0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe        30000000000000000
# 1      0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe         3000000000000000
# 2      0xc35A5FEc6BE6957899E15559Be252Db882220b37        30000000000000000
# 3      0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe         3000000000000000
# 4      0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe       200000000000000000
# ...                                           ...                      ...
# 40750  0x73A1Bb338613291AC6530870Fe2c5D354BFEC17e                600000000
# 40751  0x818ec19eBE023b4774799fdB39F0b20aF39571FE     99000000000000000000
# 40752  0x1eC627158650fF5dB5d6FCe7C1Ed6e0086D94F5f  52555000000000000000000
# 40753  0x1eC627158650fF5dB5d6FCe7C1Ed6e0086D94F5f  52555000000000000000000
# 40754  0xe9bAB3816a139827fE218D58699097B359680380      2250000000000000000
#
#       maximum_repayment_amount  loan_duration_d     loan_apr  loan_start_time  \
# 0            35000000000000000                7   869.047619       1589580384
# 1             3100000000000000                7   173.809524       1589623507
# 2            30100000000000000                7    17.380952       1589628655
# 3             3010000000000000                7    17.380952       1589631935
# 4           250000000000000000                7  1303.571429       1589633522
# ...                        ...              ...          ...              ...
# 40750                622191781               30    45.000000       1682367647
# 40751     99732329000000000000               30     9.000003       1682362607
# 40752  52986526945000000000000               30     9.990000       1682363507
# 40753  52986526945000000000000               30     9.990000       1682363555
# 40754      2318178000000000000               14    78.999905       1682367131
#
#                            date                      loan_erc20denomination  \
# 0      2020-05-15T22:06:24.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 1      2020-05-16T10:05:07.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 2      2020-05-16T11:30:55.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 3      2020-05-16T12:25:35.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 4      2020-05-16T12:52:02.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# ...                         ...                                         ...
# 40750  2023-04-24T20:20:47.000Z  0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48
# 40751  2023-04-24T18:56:47.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 40752  2023-04-24T19:11:47.000Z  0x6B175474E89094C44Da98b954EedeAC495271d0F
# 40753  2023-04-24T19:12:35.000Z  0x6B175474E89094C44Da98b954EedeAC495271d0F
# 40754  2023-04-24T20:12:11.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
#
#        block_num                                   transaction_hash  \
# 0       10073259  0x7c7675a6613ddaded0b187314c2edd3ad3c5428a7a14...
# 1       10076484  0x937a5320404c0c835f2739c84b229ef837a9f0b0ef92...
# 2       10076867  0xf331e9fb8341f1b644e0edfe599a56402836808b2570...
# 3       10077100  0x330e8f56d4f6eb07392d8c23858eda1cada42c550ed9...
# 4       10077208  0x9bd7a9da5505b3d42152dd5f971378daeb6a0e74a0ef...
# ...          ...                                                ...
# 40750   17118481  0xfd2ae7f526cc0dd5d154e4a24b7d5531201e1b70fab5...
# 40751   17118066  0x1ae59b0a6f064d5877d1cb7daf822fbeb6d861be40f8...
# 40752   17118141  0xc95639c3fe6ffd6062ab914ce7dcbf693ccbdd454573...
# 40753   17118145  0x837a2f77681fe4b192c1721eaf042ea7518a5315a916...
# 40754   17118438  0x49a1183d64fa141041920c35ee637713bc411390f112...
#
#          gas_price  gas_limit  gas_used  cumulative_gas_used  \
# 0      17782723583    1000000    436882              3212704
# 1      19755020080     500000    441106              9710213
# 2      12100000000     500000    403060              9269753
# 3      15430188679     500000    428215              2708977
# 4      14000000000     500000    441098              9403518
# ...            ...        ...       ...                  ...
# 40750  46000000000     490745    480957              6695289
# 40751  52268898606     499431    484843             10219934
# 40752  49319816314     522723    512935              6979618
# 40753  45264530207     505623    495835             15156691
# 40754  56169185321     512105    502317             12210820
#
#        effective_gas_price  repaid  liquidated          loan_repaid_time  \
# 0              17782723583     1.0         NaN  2020-05-16T09:25:02.000Z
# 1              19755020080     1.0         NaN  2020-05-16T11:50:26.000Z
# 2              12100000000     1.0         NaN  2020-05-16T12:20:16.000Z
# 3              15430188679     1.0         NaN  2020-05-16T12:28:51.000Z
# 4              14000000000     1.0         NaN  2020-05-16T12:56:27.000Z
# ...                    ...     ...         ...                       ...
# 40750          46000000000     NaN         NaN                       NaN
# 40751          52268898606     NaN         NaN                       NaN
# 40752          49319816314     NaN         NaN                       NaN
# 40753          45264530207     NaN         NaN                       NaN
# 40754          56169185321     NaN         NaN                       NaN
#
#       repaid_amount_paid_to_lender  \
# 0                34750000000000000
# 1                 3095000000000000
# 2                30095000000000000
# 3                 3009500000000000
# 4               247500000000000000
# ...                            ...
# 40750                          NaN
# 40751                          NaN
# 40752                          NaN
# 40753                          NaN
# 40754                          NaN
#
#                                  repaid_transaction_hash  repaid_gas_price  \
# 0      0x3e24b9cd4c0208acc25259d4fcbddf75b48a554d6814...      1.900000e+10
# 1      0x59d1c26160b7bdde716b380364b506e056d852ac1b36...      1.697449e+10
# 2      0xfa036df32071d8b4f301b34aa2893bc0499db7e79bf1...      1.320000e+10
# 3      0x8f70de246186ae66da45404c856b9db431b26bfcbe7f...      1.310000e+10
# 4      0x0eaead5004befd758f4f4a7c04241098eaa9948192e2...      2.100000e+10
# ...                                                  ...               ...
# 40750                                                NaN               NaN
# 40751                                                NaN               NaN
# 40752                                                NaN               NaN
# 40753                                                NaN               NaN
# 40754                                                NaN               NaN
#
#        repaid_gas_limit  repaid_gas_used  repaid_cumulative_gas_used  \
# 0              500000.0         120497.0                   9549420.0
# 1              500000.0         122603.0                   9470068.0
# 2              500000.0         132834.0                   4140219.0
# 3              500000.0         122603.0                   9570320.0
# 4              500000.0         132203.0                   4175144.0
# ...                 ...              ...                         ...
# 40750               NaN              NaN                         NaN
# 40751               NaN              NaN                         NaN
# 40752               NaN              NaN                         NaN
# 40753               NaN              NaN                         NaN
# 40754               NaN              NaN                         NaN
#
#        repaid_effective_gas_price  repaid_admin_fee loan_liquidation_date  \
# 0                    1.900000e+10   250000000000000                   NaN
# 1                    1.697449e+10     5000000000000                   NaN
# 2                    1.320000e+10     5000000000000                   NaN
# 3                    1.310000e+10      500000000000                   NaN
# 4                    2.100000e+10  2500000000000000                   NaN
# ...                           ...               ...                   ...
# 40750                         NaN               NaN                   NaN
# 40751                         NaN               NaN                   NaN
# 40752                         NaN               NaN                   NaN
# 40753                         NaN               NaN                   NaN
# 40754                         NaN               NaN                   NaN
#
#       liquidated_transaction_hash  liquidated_gas_price  liquidated_gas_limit  \
# 0                             NaN                   NaN                   NaN
# 1                             NaN                   NaN                   NaN
# 2                             NaN                   NaN                   NaN
# 3                             NaN                   NaN                   NaN
# 4                             NaN                   NaN                   NaN
# ...                           ...                   ...                   ...
# 40750                         NaN                   NaN                   NaN
# 40751                         NaN                   NaN                   NaN
# 40752                         NaN                   NaN                   NaN
# 40753                         NaN                   NaN                   NaN
# 40754                         NaN                   NaN                   NaN
#
#        liquidated_gas_used  liquidated_cumulative_gas_used  \
# 0                      NaN                             NaN
# 1                      NaN                             NaN
# 2                      NaN                             NaN
# 3                      NaN                             NaN
# 4                      NaN                             NaN
# ...                    ...                             ...
# 40750                  NaN                             NaN
# 40751                  NaN                             NaN
# 40752                  NaN                             NaN
# 40753                  NaN                             NaN
# 40754                  NaN                             NaN
#
#        liquidated_effective_gas_price loan_no_cleaned
# 0                                 NaN               0
# 1                                 NaN               1
# 2                                 NaN               2
# 3                                 NaN               3
# 4                                 NaN               4
# ...                               ...             ...
# 40750                             NaN           33827
# 40751                             NaN           33811
# 40752                             NaN           33814
# 40753                             NaN           33817
# 40754                             NaN           33826
#
# [40755 rows x 39 columns]

# %%
display(mq['loan_id_cleaned'])
display(nftfi['loan_no_cleaned'])
# Out:
# 0         4882
# 1          733
# 2        31180
# 3        27589
# 4        23358
#          ...
# 22037    20293
# 22038    20292
# 22039    20291
# 22040    20290
# 22041    20288
# Name: loan_id_cleaned, Length: 22042, dtype: object
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#          ...
# 40750    33827
# 40751    33811
# 40752    33814
# 40753    33817
# 40754    33826
# Name: loan_no_cleaned, Length: 40755, dtype: object

# %%
mq.shape[0], nftfi.shape[0]
# Out:
# (22042, 40755)

# %%
# Check minimum and maximum dates of each table
print(f"min mq date: {mq.block_timestamp.min()}; max mq date: {mq.block_timestamp.max()}")
print(f"min nftfi date: {nftfi.date.min()}; max nftfi date: {nftfi.date.max()}")
# Out:
# min mq date: 2020-10-15 18:15:24.000000 UTC; max mq date: 2023-05-18 12:41:47.000000 UTC
# min nftfi date: 2020-05-15T22:06:24.000Z; max nftfi date: 2023-04-24T20:20:47.000Z

# %%
mq.loc[mq.loan_id_cleaned.duplicated()==True].sort_values('loan_id_cleaned')
# Out:
#                                         transaction_hash  \
# 17754  0x853126067767f771040544ccf90f6a6e39c6328c442d...
# 11490  0x40739bfb7332c87bcb4b7037a8d15cb11c68c759a6cc...
# 19867  0x7b8f201bef86240d984f82ead58e61779e480c786941...
# 8061   0xe4d7745df19b8e93e11fa5bb6fd0ab2472de80849628...
# 8060   0x3c5db775c42168bca6b3df3ca028b43136931bfaaadd...
# ...                                                  ...
# 19719  0xfbb30b44e9824770d84a15361b094e6a9a8aea33c338...
# 19718  0x911401ad5f892108602b797b5d94a04e7e236368350e...
# 19235  0x2883f40fd8879958105f438469292bbddd538609bda7...
# 20299  0x8460d4842534c4ae3c7aafbe610088636e4f2f8c9562...
# 7681   0xe83959d5b55171b29a6f1a69da4bc99a03e480713eed...
#
#                       block_timestamp  loan_id  \
# 17754  2021-07-25 21:41:20.000000 UTC    -1001
# 11490  2021-07-25 22:23:33.000000 UTC    -1002
# 19867  2022-04-22 22:45:07.000000 UTC     1009
# 8061   2022-04-22 23:29:20.000000 UTC     1010
# 8060   2022-04-22 23:41:27.000000 UTC     1011
# ...                               ...      ...
# 19719  2022-04-21 22:54:16.000000 UTC      869
# 19718  2022-04-21 23:05:30.000000 UTC      870
# 19235  2022-04-22 00:44:31.000000 UTC      889
# 20299  2022-04-22 04:20:25.000000 UTC      949
# 7681   2022-04-22 13:24:29.000000 UTC      968
#
#                                        to_address  \
# 17754  0xae00360a54b97723c236093bd272b1b06efc14cd
# 11490  0xade44991d931ca62e4b56f59a7a8e9160067f48a
# 19867  0xd2db35024d1817defd4bb8617bdd7f05c07a870e
# 8061   0xb2a2a6a69e7a0ad66943f4c2869d45a9919cf740
# 8060   0xb2a2a6a69e7a0ad66943f4c2869d45a9919cf740
# ...                                           ...
# 19719  0xc35f3f92a9f27a157b309a9656cfea30e5c9cce3
# 19718  0xc35f3f92a9f27a157b309a9656cfea30e5c9cce3
# 19235  0x648a58121dc0de4436837dc585ded4fa5fba6d3e
# 20299  0x8ad59324604e2170f45c12a5ba992e80648987ed
# 7681   0xb2a2a6a69e7a0ad66943f4c2869d45a9919cf740
#
#                                      from_address  principal_amount  \
# 17754  0x82ba2d6184cb07c46687a89a62c4a9b5c584e87d            30.000
# 11490  0x6954d0255cfed71d55ad8b371b4170b8bf7709dc             0.200
# 19867  0x768f2a7ccdfde9ebdfd5cea8b635dd590cb3a3f1            24.000
# 8061   0x613593559d211a55ee00797b1aed4abcca214209             0.385
# 8060   0x613593559d211a55ee00797b1aed4abcca214209             0.385
# ...                                           ...               ...
# 19719  0x3caf4d085a67e4beb3ec5364704881172b1830c8             9.000
# 19718  0x3caf4d085a67e4beb3ec5364704881172b1830c8            10.110
# 19235  0x0aff497bd016000185b1c8302fa98a88ff4a4178             9.000
# 20299  0xcb43971645190ca9181f26e4f40eade20d51f39f             9.500
# 7681   0x0aff497bd016000185b1c8302fa98a88ff4a4178             0.385
#
#        repayment_amount                               erc20_address  \
# 17754         30.493151  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 11490          0.204932  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 19867         24.710137  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 8061           0.396814  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 8060           0.396814  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ...                 ...                                         ...
# 19719          9.887671  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 19718         11.107151  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 19235          9.669378  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 20299         10.413562  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 7681           0.413479  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#       erc20_name                        due_date  duration_in_days       apr  \
# 17754       wETH  2021-08-24 21:41:20.000000 UTC              30.0  0.200000
# 11490       wETH  2021-10-23 22:23:33.000000 UTC              90.0  0.100000
# 19867       wETH  2022-05-22 22:45:07.000000 UTC              30.0  0.360000
# 8061        wETH  2022-05-06 23:29:20.000000 UTC              14.0  0.800020
# 8060        wETH  2022-05-06 23:41:27.000000 UTC              14.0  0.800020
# ...          ...                             ...               ...       ...
# 19719       wETH  2022-07-20 22:54:16.000000 UTC              90.0  0.400000
# 19718       wETH  2022-07-20 23:05:30.000000 UTC              90.0  0.400000
# 19235       wETH  2022-05-22 00:44:31.000000 UTC              30.0  0.904900
# 20299       wETH  2022-07-21 04:20:25.000000 UTC              90.0  0.390000
# 7681        wETH  2022-05-22 13:24:29.000000 UTC              30.0  0.899986
#
#       token_id                          collection_address protocol  \
# 17754    18237  0x7bd29408f11d2bfc23c34f18275bbf23bb716bc7    nftfi
# 11490   150280  0x50f5474724e0ee42d9a4e711ccfb275809fd6d4a    nftfi
# 19867     6049  0x8a90cab2b38dba80c64b7734e58ee1db38b8992e    nftfi
# 8061      3030  0x42069abfe407c60cf4ae4112bedead391dba1cdb    nftfi
# 8060      2391  0x42069abfe407c60cf4ae4112bedead391dba1cdb    nftfi
# ...        ...                                         ...      ...
# 19719     5554  0x8a90cab2b38dba80c64b7734e58ee1db38b8992e    nftfi
# 19718     5592  0x8a90cab2b38dba80c64b7734e58ee1db38b8992e    nftfi
# 19235     2225  0x8a90cab2b38dba80c64b7734e58ee1db38b8992e    nftfi
# 20299     5294  0x8a90cab2b38dba80c64b7734e58ee1db38b8992e    nftfi
# 7681      3355  0x42069abfe407c60cf4ae4112bedead391dba1cdb    nftfi
#
#          amt_in_usd  roll_over  block_number p2p_p2pool loan_id_cleaned
# 17754  64742.160000      False      12897889        p2p            1001
# 11490    432.446340      False      12898074        p2p            1002
# 19867  71154.048000      False      14637423        p2p            1009
# 8061    1139.224394      False      14637621        p2p            1010
# 8060    1139.224394      False      14637680        p2p            1011
# ...             ...        ...           ...        ...             ...
# 19719  27028.056600      False      14631062        p2p             869
# 19718  30167.461530      False      14631114        p2p             870
# 19235  26857.404000      False      14631573        p2p             889
# 20299  28458.008100      False      14632509        p2p             949
# 7681    1155.583621      False      14634936        p2p             968
#
# [1894 rows x 20 columns]

# %%
nftfi.head(2)
# Out:
#            loan_no  id  loan_contract  status  \
# 0  v1.loan.fixed-0   0  v1.loan.fixed  repaid
# 1  v1.loan.fixed-1   1  v1.loan.fixed  repaid
#
#                                      borrower  \
# 0  0xc35A5FEc6BE6957899E15559Be252Db882220b37
# 1  0xc35A5FEc6BE6957899E15559Be252Db882220b37
#
#                                        lender loan_principal_amount  \
# 0  0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe     30000000000000000
# 1  0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe      3000000000000000
#
#   maximum_repayment_amount  loan_duration_d    loan_apr  loan_start_time  \
# 0        35000000000000000                7  869.047619       1589580384
# 1         3100000000000000                7  173.809524       1589623507
#
#                        date                      loan_erc20denomination  \
# 0  2020-05-15T22:06:24.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
# 1  2020-05-16T10:05:07.000Z  0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2
#
#    block_num                                   transaction_hash    gas_price  \
# 0   10073259  0x7c7675a6613ddaded0b187314c2edd3ad3c5428a7a14...  17782723583
# 1   10076484  0x937a5320404c0c835f2739c84b229ef837a9f0b0ef92...  19755020080
#
#    gas_limit  gas_used  cumulative_gas_used  effective_gas_price  repaid  \
# 0    1000000    436882              3212704          17782723583     1.0
# 1     500000    441106              9710213          19755020080     1.0
#
#    liquidated          loan_repaid_time repaid_amount_paid_to_lender  \
# 0         NaN  2020-05-16T09:25:02.000Z            34750000000000000
# 1         NaN  2020-05-16T11:50:26.000Z             3095000000000000
#
#                              repaid_transaction_hash  repaid_gas_price  \
# 0  0x3e24b9cd4c0208acc25259d4fcbddf75b48a554d6814...      1.900000e+10
# 1  0x59d1c26160b7bdde716b380364b506e056d852ac1b36...      1.697449e+10
#
#    repaid_gas_limit  repaid_gas_used  repaid_cumulative_gas_used  \
# 0          500000.0         120497.0                   9549420.0
# 1          500000.0         122603.0                   9470068.0
#
#    repaid_effective_gas_price repaid_admin_fee loan_liquidation_date  \
# 0                1.900000e+10  250000000000000                   NaN
# 1                1.697449e+10    5000000000000                   NaN
#
#   liquidated_transaction_hash  liquidated_gas_price  liquidated_gas_limit  \
# 0                         NaN                   NaN                   NaN
# 1                         NaN                   NaN                   NaN
#
#    liquidated_gas_used  liquidated_cumulative_gas_used  \
# 0                  NaN                             NaN
# 1                  NaN                             NaN
#
#    liquidated_effective_gas_price loan_no_cleaned
# 0                             NaN               0
# 1                             NaN               1

# %%
print('MQ:\n')
print("Are loan_id unique? Once grouped by unique, the counts are: ")
mq_loan_id_count = pd.DataFrame(mq.groupby('loan_id').agg('count')['transaction_hash'])
mq_loan_id_count = mq_loan_id_count.reset_index()

display(mq_loan_id_count['transaction_hash'].unique())
display(mq_loan_id_count.loc[mq_loan_id_count['transaction_hash']>1])
duplicated_mq_loans = pd.merge(left=mq, right=mq_loan_id_count.loc[mq_loan_id_count['transaction_hash']>1], left_on='loan_id', right_on='loan_id')
display(duplicated_mq_loans)
display(duplicated_mq_loans.amt_in_usd.sum())
print("Are loan_id_cleaned unique? Once grouped by loan_id_cleaned, the counts are: ")
display(mq.groupby('loan_id_cleaned').agg('count')['transaction_hash'].unique())
# Out:
# MQ:
#
# Are loan_id unique? Once grouped by unique, the counts are:
# array([1, 2])
#        loan_id  transaction_hash
# 177      -6545                 2
# 537      -5752                 2
# 538      -5751                 2
# 14879    21523                 2
# 16152    24224                 2
# 19041    30521                 2
# 19042    30522                 2
# 19043    30523                 2
#                                    transaction_hash_x  \
# 0   0x7b88f5fb4c44e2ad1382c9f2174a077d15d628878e85...
# 1   0x7b88f5fb4c44e2ad1382c9f2174a077d15d628878e85...
# 2   0xbbd45783e2cd294f86ec604831eeeca7be8bd844818e...
# 3   0xbbd45783e2cd294f86ec604831eeeca7be8bd844818e...
# 4   0x205c9f50b22b5a4751b14e09efb1eacc757ede76ca42...
# 5   0x205c9f50b22b5a4751b14e09efb1eacc757ede76ca42...
# 6   0xd5f969b32332020a8e7129e4aa2f20a5bff446b31e00...
# 7   0xd5f969b32332020a8e7129e4aa2f20a5bff446b31e00...
# 8   0xb45fb78243aa6c0420fbb40e2c8cd1cf420eb914d003...
# 9   0xb45fb78243aa6c0420fbb40e2c8cd1cf420eb914d003...
# 10  0x41489dbe078f7e9982aa8c5ed2bf521c00f51ff57ac9...
# 11  0x41489dbe078f7e9982aa8c5ed2bf521c00f51ff57ac9...
# 12  0x5d215283e0326ebddc63178230b83a1b00612e9fe30d...
# 13  0x5d215283e0326ebddc63178230b83a1b00612e9fe30d...
# 14  0xfb83f7b98831eec2595e1af36e064057cfac3018b155...
# 15  0xfb83f7b98831eec2595e1af36e064057cfac3018b155...
#
#                    block_timestamp  loan_id  \
# 0   2022-04-04 06:24:18.000000 UTC    -6545
# 1   2022-04-04 06:24:18.000000 UTC    -6545
# 2   2023-01-18 06:03:35.000000 UTC    21523
# 3   2023-01-18 06:03:35.000000 UTC    21523
# 4   2023-03-26 16:43:47.000000 UTC    30522
# 5   2023-03-26 16:43:47.000000 UTC    30522
# 6   2023-03-26 16:43:11.000000 UTC    30521
# 7   2023-03-26 16:43:11.000000 UTC    30521
# 8   2022-03-20 17:57:17.000000 UTC    -5752
# 9   2022-03-20 17:57:17.000000 UTC    -5752
# 10  2022-03-20 17:55:51.000000 UTC    -5751
# 11  2022-03-20 17:55:51.000000 UTC    -5751
# 12  2023-03-26 16:44:11.000000 UTC    30523
# 13  2023-03-26 16:44:11.000000 UTC    30523
# 14  2023-02-06 20:30:11.000000 UTC    24224
# 15  2023-02-06 20:30:11.000000 UTC    24224
#
#                                     to_address  \
# 0   0x648a58121dc0de4436837dc585ded4fa5fba6d3e
# 1   0x648a58121dc0de4436837dc585ded4fa5fba6d3e
# 2   0x45d1a3acee4b57f5bb078a14d993364f80e86657
# 3   0x45d1a3acee4b57f5bb078a14d993364f80e86657
# 4   0x48cf6acbcba1c8fe470827c6739a80c360ccc326
# 5   0x48cf6acbcba1c8fe470827c6739a80c360ccc326
# 6   0x48cf6acbcba1c8fe470827c6739a80c360ccc326
# 7   0x48cf6acbcba1c8fe470827c6739a80c360ccc326
# 8   0x6744a9c6e3a9b8f7243ace5b20d51a500fcd0353
# 9   0x6744a9c6e3a9b8f7243ace5b20d51a500fcd0353
# 10  0x6744a9c6e3a9b8f7243ace5b20d51a500fcd0353
# 11  0x6744a9c6e3a9b8f7243ace5b20d51a500fcd0353
# 12  0xbec69dfce4c1fa8b7843fee1ca85788d84a86b06
# 13  0xbec69dfce4c1fa8b7843fee1ca85788d84a86b06
# 14  0x910d44c699c24cddd03ce8e7e8cc40835464fb89
# 15  0x910d44c699c24cddd03ce8e7e8cc40835464fb89
#
#                                   from_address  principal_amount  \
# 0   0x0aff497bd016000185b1c8302fa98a88ff4a4178              1.20
# 1   0x0aff497bd016000185b1c8302fa98a88ff4a4178              1.20
# 2   0xebd0db1bfaa50e7abe52412644e968166f349755              0.90
# 3   0xebd0db1bfaa50e7abe52412644e968166f349755              0.90
# 4   0x0b8428004ab7fea256dbc6e7c6412381cb173e8a              0.60
# 5   0x0b8428004ab7fea256dbc6e7c6412381cb173e8a              0.60
# 6   0x0b8428004ab7fea256dbc6e7c6412381cb173e8a              0.60
# 7   0x0b8428004ab7fea256dbc6e7c6412381cb173e8a              0.60
# 8   0xdef310bddbd0e2a524775505a134a86b6a583a6b              0.75
# 9   0xdef310bddbd0e2a524775505a134a86b6a583a6b              0.75
# 10  0xdef310bddbd0e2a524775505a134a86b6a583a6b              0.75
# 11  0xdef310bddbd0e2a524775505a134a86b6a583a6b              0.75
# 12  0x1797b4235473fbe0e7e44322f01c1b5618ebda41              1.00
# 13  0x1797b4235473fbe0e7e44322f01c1b5618ebda41              1.00
# 14  0x35fa3c19cf39674353025234ed001bcbb36af35c              0.31
# 15  0x35fa3c19cf39674353025234ed001bcbb36af35c              0.31
#
#     repayment_amount                               erc20_address erc20_name  \
# 0           1.289250  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 1           1.289250  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 2           0.923819  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 3           0.923819  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 4           0.618181  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 5           0.618181  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 6           0.618181  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 7           0.618181  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 8           0.775890  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 9           0.775890  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 10          0.775890  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 11          0.775890  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 12          1.023836  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 13          1.023836  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 14          0.324014  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 15          0.324014  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
#
#                           due_date  duration_in_days       apr token_id  \
# 0   2022-05-04 06:24:18.000000 UTC              30.0  0.905000      818
# 1   2022-05-04 06:24:18.000000 UTC              30.0  0.905000      818
# 2   2023-02-01 06:03:35.000000 UTC              14.0  0.689995     1662
# 3   2023-02-01 06:03:35.000000 UTC              14.0  0.689995     1662
# 4   2023-04-09 16:43:47.000000 UTC              14.0  0.790008      365
# 5   2023-04-09 16:43:47.000000 UTC              14.0  0.790008      365
# 6   2023-04-09 16:43:11.000000 UTC              14.0  0.790008      323
# 7   2023-04-09 16:43:11.000000 UTC              14.0  0.790008      323
# 8   2022-04-03 17:57:17.000000 UTC              14.0  0.900000    15130
# 9   2022-04-03 17:57:17.000000 UTC              14.0  0.900000    15130
# 10  2022-04-03 17:55:51.000000 UTC              14.0  0.900000    16202
# 11  2022-04-03 17:55:51.000000 UTC              14.0  0.900000    16202
# 12  2023-04-25 16:44:11.000000 UTC              30.0  0.290000    14093
# 13  2023-04-25 16:44:11.000000 UTC              30.0  0.290000    14093
# 14  2023-03-08 20:30:11.000000 UTC              30.0  0.550012    32395
# 15  2023-03-08 20:30:11.000000 UTC              30.0  0.550012    32395
#
#                             collection_address protocol   amt_in_usd  \
# 0   0x2acab3dea77832c09420663b0e1cb386031ba17b    nftfi  4208.424360
# 1   0x2acab3dea77832c09420663b0e1cb386031ba17b    nftfi  4208.424360
# 2   0x394e3d3044fc89fcdd966d3cb35ac0b32b0cda91    nftfi  1428.824790
# 3   0x394e3d3044fc89fcdd966d3cb35ac0b32b0cda91    nftfi  1428.824790
# 4   0x64a1c0937728d8d2fa8cd81ef61a9c860b7362db    nftfi  1058.607600
# 5   0x64a1c0937728d8d2fa8cd81ef61a9c860b7362db    nftfi  1058.607600
# 6   0x64a1c0937728d8d2fa8cd81ef61a9c860b7362db    nftfi  1058.607600
# 7   0x64a1c0937728d8d2fa8cd81ef61a9c860b7362db    nftfi  1058.607600
# 8   0x86c10d10eca1fca9daf87a279abccabe0063f247    nftfi  2137.879425
# 9   0x86c10d10eca1fca9daf87a279abccabe0063f247    nftfi  2137.879425
# 10  0x86c10d10eca1fca9daf87a279abccabe0063f247    nftfi  2137.879425
# 11  0x86c10d10eca1fca9daf87a279abccabe0063f247    nftfi  2137.879425
# 12  0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a    nftfi  1764.346000
# 13  0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a    nftfi  1764.346000
# 14  0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a    nftfi   511.035868
# 15  0x942bc2d3e7a589fe5bd4a5c6ef9727dfd82f5c8a    nftfi   511.035868
#
#     roll_over  block_number p2p_p2pool loan_id_cleaned  transaction_hash_y
# 0       False      14517889        p2p            6545                   2
# 1       False      14517889        p2p            6545                   2
# 2       False      16431774        p2p           21523                   2
# 3       False      16431774        p2p           21523                   2
# 4       False      16912865        p2p           30522                   2
# 5       False      16912865        p2p           30522                   2
# 6       False      16912862        p2p           30521                   2
# 7       False      16912862        p2p           30521                   2
# 8       False      14424722        p2p            5752                   2
# 9       False      14424722        p2p            5752                   2
# 10      False      14424716        p2p            5751                   2
# 11      False      14424716        p2p            5751                   2
# 12      False      16912867        p2p           30523                   2
# 13      False      16912867        p2p           30523                   2
# 14      False      16572143        p2p           24224                   2
# 15      False      16572143        p2p           24224                   2
# 28611.210136
# Are loan_id_cleaned unique? Once grouped by loan_id_cleaned, the counts are:
# array([1, 2, 3])

# %%
print(f"duplicate lines in MQ dataset {mq.shape[0] - mq.drop_duplicates().shape[0]}")
print(f"duplicate lines in nftfi dataset {nftfi.shape[0] - nftfi.drop_duplicates().shape[0]}")
# Out:
# duplicate lines in MQ dataset 8
# duplicate lines in nftfi dataset 0

# %% [markdown]
# ## Clean raw NFTfi dataset

# %%
# nftfi.dtypes

# %%
nftfi['date'] = pd.to_datetime(nftfi['date'], format="%Y-%m-%d %H:%M:%S%z")
nftfi['loan_start_time'] = pd.to_datetime(nftfi['loan_start_time'], format="%Y-%m-%d %H:%M:%S%z")
nftfi['loan_repaid_time'] = pd.to_datetime(nftfi['loan_repaid_time'], format="%Y-%m-%d %H:%M:%S%z")

# Remove invalid values
nftfi.replace(r"#DIV/0!", np.nan, regex=True, inplace=True)
nftfi.replace(r"#N/A", "", regex=True, inplace=True)

# Divide loanPrincipalAmount and maximumRepaymentAmount by ETH <> WEI i.e. 1^18
columns_to_clean = ['loan_principal_amount', 'maximum_repayment_amount', 'maximum_repayment_amount']
for col in columns_to_clean:
    nftfi[col] = nftfi[col].astype(np.float64)
    nftfi[col] /= 10 ** 18
# nftfi['no_of_days'] = nftfi['no_of_days'].astype(np.float64)
nftfi = nftfi.rename(columns={'loan_apr': 'apr'})
nftfi['apr'] = nftfi['apr'].astype(np.float64)

# Drop last column as it is unnamed
nftfi = nftfi.drop('', axis=1, errors='ignore')

# set BOOL columns to bool type
cols = ['repaid', 'liquidated']
nftfi['repaid'] = nftfi['repaid'].fillna(False)
nftfi['repaid'] = nftfi['repaid'].replace('', False)
for col in cols:
    # nftfi[col] = nftfi[col].astype('boolean')
    nftfi[col] = nftfi[col].map({'True': True, 'False': False})
    nftfi[col] = nftfi[col].astype(bool)
nftfi['repaid'] = nftfi['repaid'].astype(bool)

# %% [markdown]
# ## Enrich datasets

# %%
# Enrich dataset with ETHUSD rate i.e. ETHPrice, then fill USDValue for USDValue from loanERC20Denomination == weth_address
weth_address = '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'.lower()
price_df = pd.read_csv('../analytics_bot_langchain/data/nftfi/eth_usd_input_data.csv')
price_df = price_df.rename(columns={'datetime': 'date'})
price_df['date'] = pd.to_datetime(price_df['date'], format='%Y-%m-%d %H:%M:%S%z')
price_df = price_df.drop(columns=['open', 'low', 'volume'])

nftfi['date'] = pd.to_datetime(nftfi['date'])
nftfi['loan_principal_amount'] = nftfi['loan_principal_amount'].astype(float)

nftfi = nftfi.sort_values(by='date')
price_df = price_df.sort_values(by='date')

nftfi = pd.merge_asof(nftfi, price_df, on='date', direction='backward')
nftfi['eth_price'] = nftfi['close']
nftfi = nftfi.drop(columns=['close'])
nftfi['loan_erc20denomination'] = nftfi['loan_erc20denomination'].astype(str).str.lower().str.strip()
nftfi.loc[nftfi['loan_erc20denomination'] == weth_address, 'usd_value'] = nftfi.loc[nftfi['loan_erc20denomination'] == weth_address]['loan_principal_amount'] * nftfi.loc[nftfi['loan_erc20denomination'] == weth_address]['eth_price']

# now map missing usd_value, e.g. for stablecoin-denominated loans
usdc_address = '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48'  # https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
usdt_address = '0xdAC17F958D2ee523a2206206994597C13D831ec7'  # https://etherscan.io/token/0xdac17f958d2ee523a2206206994597c13d831ec7
dai_address = '0x6B175474E89094C44Da98b954EedeAC495271d0F'  # https://etherscan.io/token/0x6b175474e89094c44da98b954eedeac495271d0f
stablecoin_addresses = [usdc_address, usdt_address, dai_address]
for stablecoin_address in stablecoin_addresses:
    stablecoin_address = stablecoin_address.lower()
    nftfi.loc[nftfi['loan_erc20denomination'] == stablecoin_address, 'usd_value'] = nftfi.loc[nftfi['loan_erc20denomination'] == stablecoin_address]['loan_principal_amount']

# %%
print('\n\nNFTfi: \n')
print("Are loan_no unique? Once grouped by unique, the counts are: ")
nftfi_loan_no_count = pd.DataFrame(nftfi.groupby('loan_no').agg('count')['borrower'])
duplicated_nftfi_loans = pd.merge(left=nftfi, right=nftfi_loan_no_count.loc[nftfi_loan_no_count['borrower']>1], left_on='loan_no', right_on='loan_no')
display(duplicated_nftfi_loans)
display(duplicated_nftfi_loans.usd_value.sum())

display(nftfi_loan_no_count['borrower'].unique())
display(nftfi_loan_no_count.loc[nftfi_loan_no_count['borrower']>1])

print("Are loan_no_cleaned unique? Once grouped by loan_id_cleaned, the counts are: ")
display(nftfi.groupby('loan_no_cleaned').agg('count')['borrower'].unique())
# Out:
# NFTfi:
#
# Are loan_no unique? Once grouped by unique, the counts are:
# Empty DataFrame
# Columns: [loan_no, id, loan_contract, status, borrower_x, lender, loan_principal_amount, maximum_repayment_amount, loan_duration_d, apr, loan_start_time, date, loan_erc20denomination, block_num, transaction_hash, gas_price, gas_limit, gas_used, cumulative_gas_used, effective_gas_price, repaid, liquidated, loan_repaid_time, repaid_amount_paid_to_lender, repaid_transaction_hash, repaid_gas_price, repaid_gas_limit, repaid_gas_used, repaid_cumulative_gas_used, repaid_effective_gas_price, repaid_admin_fee, loan_liquidation_date, liquidated_transaction_hash, liquidated_gas_price, liquidated_gas_limit, liquidated_gas_used, liquidated_cumulative_gas_used, liquidated_effective_gas_price, loan_no_cleaned, high, eth_price, usd_value, borrower_y]
# Index: []
# 0.0
# array([1])
# Empty DataFrame
# Columns: [borrower]
# Index: []
# Are loan_no_cleaned unique? Once grouped by loan_id_cleaned, the counts are:
# array([1, 2])

# %% [markdown]
# ## Enrich nftfi table with ERC20 denominations

# %%
# Check if it can be due to missing token
usdc_address = '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48'  # https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
usdt_address = '0xdAC17F958D2ee523a2206206994597C13D831ec7'  # https://etherscan.io/token/0xdac17f958d2ee523a2206206994597c13d831ec7
dai_address = '0x6B175474E89094C44Da98b954EedeAC495271d0F'  # https://etherscan.io/token/0x6b175474e89094c44da98b954eedeac495271d0f
weth_address = '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'

stablecoin_addresses = [usdc_address, usdt_address, dai_address, weth_address]

stablecoin_names = ['usdc', 'usdt', 'dai', 'weth']
for stablecoin_address, stablecoin_name in zip(stablecoin_addresses, stablecoin_names):
    stablecoin_address = stablecoin_address.lower()
    nftfi.loc[nftfi['loan_erc20denomination'] == stablecoin_address, 'loan_erc20denomination_name'] = stablecoin_name

# %%
# Confirm that the above addresses matches the one available in MQ dataset:
mq.erc20_address.unique()
# Out:
# array(['0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2',
#        '0x6b175474e89094c44da98b954eedeac495271d0f',
#        '0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48'], dtype=object)

# %% [markdown]
# #### Enrich NFTfi table with loan types

# %%
nftfi['loan_type'] = nftfi.loan_no.astype(str).str.split('-').apply(lambda x: x[0]+'-'+x[1] if len(x) >2 else x[0])
nftfi['loan_type'].unique()
# Out:
# array(['v1.loan.fixed', 'v2.loan.fixed', 'v2-1.loan.fixed',
#        'v2.loan.fixed.collection'], dtype=object)

# %% [markdown]
# ## Compute April subset for each table

# %%
april_mq = mq.loc[mq['block_timestamp'] >= '2023-04-01'].loc[mq['block_timestamp'] < '2023-05-01']
april_mq.shape
# Out:
# (1852, 20)

# %%
april_nftfi = nftfi.loc[nftfi['date'] >= '2023-04-01'].loc[nftfi['date'] < '2023-05-01']
april_nftfi.shape
# Out:
# (2784, 44)

# %% [markdown]
# #### Check for duplicates

# %%
april_nftfi.loc[april_nftfi.loan_no_cleaned.duplicated()== True]
# Out:
# Empty DataFrame
# Columns: [loan_no, id, loan_contract, status, borrower, lender, loan_principal_amount, maximum_repayment_amount, loan_duration_d, apr, loan_start_time, date, loan_erc20denomination, block_num, transaction_hash, gas_price, gas_limit, gas_used, cumulative_gas_used, effective_gas_price, repaid, liquidated, loan_repaid_time, repaid_amount_paid_to_lender, repaid_transaction_hash, repaid_gas_price, repaid_gas_limit, repaid_gas_used, repaid_cumulative_gas_used, repaid_effective_gas_price, repaid_admin_fee, loan_liquidation_date, liquidated_transaction_hash, liquidated_gas_price, liquidated_gas_limit, liquidated_gas_used, liquidated_cumulative_gas_used, liquidated_effective_gas_price, loan_no_cleaned, high, eth_price, usd_value, loan_erc20denomination_name, loan_type]
# Index: []

# %%
april_mq.loc[april_mq.loan_id_cleaned.duplicated()== True]
# Out:
# Empty DataFrame
# Columns: [transaction_hash, block_timestamp, loan_id, to_address, from_address, principal_amount, repayment_amount, erc20_address, erc20_name, due_date, duration_in_days, apr, token_id, collection_address, protocol, amt_in_usd, roll_over, block_number, p2p_p2pool, loan_id_cleaned]
# Index: []

# %%
april_nftfi.loc[april_nftfi.loan_no_cleaned.duplicated()== True]
# Out:
# Empty DataFrame
# Columns: [loan_no, id, loan_contract, status, borrower, lender, loan_principal_amount, maximum_repayment_amount, loan_duration_d, apr, loan_start_time, date, loan_erc20denomination, block_num, transaction_hash, gas_price, gas_limit, gas_used, cumulative_gas_used, effective_gas_price, repaid, liquidated, loan_repaid_time, repaid_amount_paid_to_lender, repaid_transaction_hash, repaid_gas_price, repaid_gas_limit, repaid_gas_used, repaid_cumulative_gas_used, repaid_effective_gas_price, repaid_admin_fee, loan_liquidation_date, liquidated_transaction_hash, liquidated_gas_price, liquidated_gas_limit, liquidated_gas_used, liquidated_cumulative_gas_used, liquidated_effective_gas_price, loan_no_cleaned, high, eth_price, usd_value, loan_erc20denomination_name, loan_type]
# Index: []

# %%
display(april_mq.head(3).sort_values('loan_id_cleaned', ascending=False))
display(april_nftfi.head(3).sort_values('loan_no_cleaned', ascending=False))
# Out:
#                                      transaction_hash  \
# 28  0xecaf8a9e276b227506ebc8acc837792370ec83d52e39...
# 82  0x2d07d7afcb6324bfc6239c6bcc9bca658a49cd2b227c...
# 2   0x0f3522aa06eb28b8cceb590ea80cbd335ab64010dab8...
#
#                    block_timestamp  loan_id  \
# 28  2023-04-28 00:40:35.000000 UTC    34311
# 82  2023-04-27 13:53:47.000000 UTC    34265
# 2   2023-04-02 09:27:59.000000 UTC    31180
#
#                                     to_address  \
# 28  0xefa755b82218dc287ed37bf6463c144ae6609076
# 82  0xa35b95b60af5205dbd02571d8d72ef83f79a28af
# 2   0xf7b18e107eb36797f4ce36de756630b9c30969ad
#
#                                   from_address  principal_amount  \
# 28  0x08f6db921b10ce9f7ec4166b9be9dc01a30c34cc           10000.0
# 82  0x1797b4235473fbe0e7e44322f01c1b5618ebda41               6.0
# 2   0x31d75becb2fe9cc60eb4877b44110aa1cdae90a5             800.0
#
#     repayment_amount                               erc20_address erc20_name  \
# 28      10082.191781  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48       USDc
# 82          6.540000  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 2         826.301370  0x6b175474e89094c44da98b954eedeac495271d0f        DAI
#
#                           due_date  duration_in_days   apr token_id  \
# 28  2023-05-28 00:40:35.000000 UTC              30.0  0.10     6096
# 82  2024-04-26 13:53:47.000000 UTC             365.0  0.09     9470
# 2   2023-06-01 09:27:59.000000 UTC              60.0  0.20     2118
#
#                             collection_address protocol  amt_in_usd  \
# 28  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi  10000.0000
# 82  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi  11261.0808
# 2   0x026224a2940bfe258d0dbe947919b62fe321f042    nftfi    800.0000
#
#     roll_over  block_number p2p_p2pool loan_id_cleaned
# 28      False      17141128        p2p           34311
# 82      False      17137936        p2p           34265
# 2       False      16960517        p2p           31180
#                               loan_no     id             loan_contract  \
# 37973  v2.loan.fixed.collection-31046  31046  v2.loan.fixed.collection
# 37972           v2-1.loan.fixed-31045  31045           v2-1.loan.fixed
# 37971           v2-1.loan.fixed-31044  31044           v2-1.loan.fixed
#
#        status                                    borrower  \
# 37973     NaN  0x58463E8ecA64FE736a26d7A2eD95B4Bc6127e268
# 37972     NaN  0x07a2CF3c078D9526Eb50Ba7AFFaBc0049827D126
# 37971  repaid  0x371267a1863080c5F39229183350e0D87d39743E
#
#                                            lender  loan_principal_amount  \
# 37973  0x3e60C12997d3Bb062530e5F7e7f0400FBB9aEcA5                  0.686
# 37972  0x064980edD7D43AbEE781f49A4e31C06Df05EcccB                  0.375
# 37971  0x9CD074f0192BB2A477DA3271bA03db4fc5cD38c7                  2.600
#
#        maximum_repayment_amount  loan_duration_d        apr  \
# 37973              7.019578e-19               30  28.302216
# 37972              4.027400e-19               30  90.000889
# 37971              2.685458e-18               30  39.989962
#
#                     loan_start_time                      date  \
# 37973 1970-01-01 00:00:01.680310871 2023-04-01 01:01:11+00:00
# 37972 1970-01-01 00:00:01.680308543 2023-04-01 00:22:23+00:00
# 37971 1970-01-01 00:00:01.680307511 2023-04-01 00:05:11+00:00
#
#                            loan_erc20denomination  block_num  \
# 37973  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950907
# 37972  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950714
# 37971  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950628
#
#                                         transaction_hash    gas_price  \
# 37973  0x57bfc3c592f00d6fad19dabbc746cba5ada6d55263bd...  19323776633
# 37972  0xa9ba08c02d21f2431178b2daa9edb4e50416948373e8...  21761128223
# 37971  0x18c7c39e8fdb35cd976872d05263f92e34d9e8b5825c...  26393453389
#
#        gas_limit  gas_used  cumulative_gas_used  effective_gas_price  repaid  \
# 37973     476002    466214             17071471          19323776633    True
# 37972     466942    461954              9657250          21761128223    True
# 37971     539029    524441              5046898          26393453389    True
#
#        liquidated          loan_repaid_time repaid_amount_paid_to_lender  \
# 37973        True                       NaT                          NaN
# 37972        True                       NaT                          NaN
# 37971        True 2023-04-24 09:17:59+00:00          2681185100000000000
#
#                                  repaid_transaction_hash  repaid_gas_price  \
# 37973                                                NaN               NaN
# 37972                                                NaN               NaN
# 37971  0xb0ca08e743122d22d09806ba5850cda85f605dee5bfc...      3.875323e+10
#
#        repaid_gas_limit  repaid_gas_used  repaid_cumulative_gas_used  \
# 37973               NaN              NaN                         NaN
# 37972               NaN              NaN                         NaN
# 37971          454254.0         240516.0                   2481228.0
#
#        repaid_effective_gas_price  repaid_admin_fee loan_liquidation_date  \
# 37973                         NaN               NaN                   NaN
# 37972                         NaN               NaN                   NaN
# 37971                3.875323e+10  4272900000000000                   NaN
#
#       liquidated_transaction_hash  liquidated_gas_price  liquidated_gas_limit  \
# 37973                         NaN                   NaN                   NaN
# 37972                         NaN                   NaN                   NaN
# 37971                         NaN                   NaN                   NaN
#
#        liquidated_gas_used  liquidated_cumulative_gas_used  \
# 37973                  NaN                             NaN
# 37972                  NaN                             NaN
# 37971                  NaN                             NaN
#
#        liquidated_effective_gas_price loan_no_cleaned     high  eth_price  \
# 37973                             NaN           31046  1821.82    1821.51
# 37972                             NaN           31045  1827.85    1825.60
# 37971                             NaN           31044  1824.45    1823.42
#
#         usd_value loan_erc20denomination_name                 loan_type
# 37973  1249.55586                        weth  v2.loan.fixed.collection
# 37972   684.60000                        weth           v2-1.loan.fixed
# 37971  4740.89200                        weth           v2-1.loan.fixed

# %%
# Determine the set of unique IDs present in MQ and not in NFTfi
len(set(list(april_mq.loan_id_cleaned)) - set(list(april_nftfi.loan_no_cleaned)))
# Out:
# 430

# %%
# Determine the set of unique IDs present in NFTfi and not in MQ's
len(set(list(april_nftfi.loan_no_cleaned)) - set(list(april_mq.loan_id_cleaned)))
# Out:
# 1362

# %%
april_mq.shape, april_nftfi.shape
# Out:
# ((1852, 20), (2784, 44))

# %%
april_nftfi.shape[0] - april_mq.shape[0]
# Out:
# 932

# %% [markdown]
# ## Compute which Loans are available in NFTfi's and not in MQ's, and the converse, by matching on transaction hashes

# %%
# how do i get all rows in df1 that are not in df2
# and all rows in df2 that are not in df1?

# Perform a full outer join on df1 and df2
full_outer = pd.merge(april_nftfi, april_mq, how='outer', on='transaction_hash', indicator=True)

# Filter out the rows that are unique to df1
unique_to_april_nftfi = full_outer[full_outer['_merge'] == 'left_only']

# Filter out the rows that are unique to df2
unique_to_april_mq = full_outer[full_outer['_merge'] == 'right_only']

# %%
print(f"number of loans unique to NFTfi relative to MQ in April 2023: {unique_to_april_nftfi.shape[0]}, i.e. {100 * round(unique_to_april_nftfi.shape[0] / april_nftfi.shape[0], 2)}%")
print(f"while in April 2023 NFTfi had {april_nftfi.shape[0]} loans while mq had {april_mq.shape[0]}, i.e. for April NFTfi has {april_nftfi.shape[0] - april_mq.shape[0]} more loans")
display(unique_to_april_nftfi.shape[0])
display(unique_to_april_nftfi.head(2))
# Out:
# number of loans unique to NFTfi relative to MQ in April 2023: 1362, i.e. 49.0%
# while in April 2023 NFTfi had 2784 loans while mq had 1852, i.e. for April NFTfi has 932 more loans
# 1362
#                           loan_no       id             loan_contract status  \
# 1           v2-1.loan.fixed-31045  31045.0           v2-1.loan.fixed    NaN
# 2  v2.loan.fixed.collection-31046  31046.0  v2.loan.fixed.collection    NaN
#
#                                      borrower  \
# 1  0x07a2CF3c078D9526Eb50Ba7AFFaBc0049827D126
# 2  0x58463E8ecA64FE736a26d7A2eD95B4Bc6127e268
#
#                                        lender  loan_principal_amount  \
# 1  0x064980edD7D43AbEE781f49A4e31C06Df05EcccB                  0.375
# 2  0x3e60C12997d3Bb062530e5F7e7f0400FBB9aEcA5                  0.686
#
#    maximum_repayment_amount  loan_duration_d      apr_x  \
# 1              4.027400e-19             30.0  90.000889
# 2              7.019578e-19             30.0  28.302216
#
#                 loan_start_time                      date  \
# 1 1970-01-01 00:00:01.680308543 2023-04-01 00:22:23+00:00
# 2 1970-01-01 00:00:01.680310871 2023-04-01 01:01:11+00:00
#
#                        loan_erc20denomination   block_num  \
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  16950714.0
# 2  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  16950907.0
#
#                                     transaction_hash     gas_price  gas_limit  \
# 1  0xa9ba08c02d21f2431178b2daa9edb4e50416948373e8...  2.176113e+10   466942.0
# 2  0x57bfc3c592f00d6fad19dabbc746cba5ada6d55263bd...  1.932378e+10   476002.0
#
#    gas_used  cumulative_gas_used  effective_gas_price repaid liquidated  \
# 1  461954.0            9657250.0         2.176113e+10   True       True
# 2  466214.0           17071471.0         1.932378e+10   True       True
#
#   loan_repaid_time repaid_amount_paid_to_lender repaid_transaction_hash  \
# 1              NaT                          NaN                     NaN
# 2              NaT                          NaN                     NaN
#
#    repaid_gas_price  repaid_gas_limit  repaid_gas_used  \
# 1               NaN               NaN              NaN
# 2               NaN               NaN              NaN
#
#    repaid_cumulative_gas_used  repaid_effective_gas_price repaid_admin_fee  \
# 1                         NaN                         NaN              NaN
# 2                         NaN                         NaN              NaN
#
#   loan_liquidation_date liquidated_transaction_hash  liquidated_gas_price  \
# 1                   NaN                         NaN                   NaN
# 2                   NaN                         NaN                   NaN
#
#    liquidated_gas_limit  liquidated_gas_used  liquidated_cumulative_gas_used  \
# 1                   NaN                  NaN                             NaN
# 2                   NaN                  NaN                             NaN
#
#    liquidated_effective_gas_price loan_no_cleaned     high  eth_price  \
# 1                             NaN           31045  1827.85    1825.60
# 2                             NaN           31046  1821.82    1821.51
#
#     usd_value loan_erc20denomination_name                 loan_type  \
# 1   684.60000                        weth           v2-1.loan.fixed
# 2  1249.55586                        weth  v2.loan.fixed.collection
#
#   block_timestamp  loan_id to_address from_address  principal_amount  \
# 1             NaN      NaN        NaN          NaN               NaN
# 2             NaN      NaN        NaN          NaN               NaN
#
#    repayment_amount erc20_address erc20_name due_date  duration_in_days  \
# 1               NaN           NaN        NaN      NaN               NaN
# 2               NaN           NaN        NaN      NaN               NaN
#
#    apr_y token_id collection_address protocol  amt_in_usd roll_over  \
# 1    NaN      NaN                NaN      NaN         NaN       NaN
# 2    NaN      NaN                NaN      NaN         NaN       NaN
#
#    block_number p2p_p2pool loan_id_cleaned     _merge
# 1           NaN        NaN             NaN  left_only
# 2           NaN        NaN             NaN  left_only

# %%
print(f"number of loans unique to MQ relative to NFTfi in April 2023: {unique_to_april_mq.shape[0]}, i.e. {100 * round(unique_to_april_mq.shape[0] / april_mq.shape[0], 2)}%")
print(f"while in April 2023 NFTfi had {april_nftfi.shape[0]} loans while mq had {april_mq.shape[0]}, i.e. for April NFTfi has {april_nftfi.shape[0] - april_mq.shape[0]} more loans")

display(unique_to_april_mq.shape[0])
display(unique_to_april_mq.head(2))
# Out:
# number of loans unique to MQ relative to NFTfi in April 2023: 430, i.e. 23.0%
# while in April 2023 NFTfi had 2784 loans while mq had 1852, i.e. for April NFTfi has 932 more loans
# 430
#      loan_no  id loan_contract status borrower lender  loan_principal_amount  \
# 2784     NaN NaN           NaN    NaN      NaN    NaN                    NaN
# 2785     NaN NaN           NaN    NaN      NaN    NaN                    NaN
#
#       maximum_repayment_amount  loan_duration_d  apr_x loan_start_time date  \
# 2784                       NaN              NaN    NaN             NaT  NaT
# 2785                       NaN              NaN    NaN             NaT  NaT
#
#      loan_erc20denomination  block_num  \
# 2784                    NaN        NaN
# 2785                    NaN        NaN
#
#                                        transaction_hash  gas_price  gas_limit  \
# 2784  0xecaf8a9e276b227506ebc8acc837792370ec83d52e39...        NaN        NaN
# 2785  0x2d07d7afcb6324bfc6239c6bcc9bca658a49cd2b227c...        NaN        NaN
#
#       gas_used  cumulative_gas_used  effective_gas_price repaid liquidated  \
# 2784       NaN                  NaN                  NaN    NaN        NaN
# 2785       NaN                  NaN                  NaN    NaN        NaN
#
#      loan_repaid_time repaid_amount_paid_to_lender repaid_transaction_hash  \
# 2784              NaT                          NaN                     NaN
# 2785              NaT                          NaN                     NaN
#
#       repaid_gas_price  repaid_gas_limit  repaid_gas_used  \
# 2784               NaN               NaN              NaN
# 2785               NaN               NaN              NaN
#
#       repaid_cumulative_gas_used  repaid_effective_gas_price repaid_admin_fee  \
# 2784                         NaN                         NaN              NaN
# 2785                         NaN                         NaN              NaN
#
#      loan_liquidation_date liquidated_transaction_hash  liquidated_gas_price  \
# 2784                   NaN                         NaN                   NaN
# 2785                   NaN                         NaN                   NaN
#
#       liquidated_gas_limit  liquidated_gas_used  \
# 2784                   NaN                  NaN
# 2785                   NaN                  NaN
#
#       liquidated_cumulative_gas_used  liquidated_effective_gas_price  \
# 2784                             NaN                             NaN
# 2785                             NaN                             NaN
#
#      loan_no_cleaned  high  eth_price  usd_value loan_erc20denomination_name  \
# 2784             NaN   NaN        NaN        NaN                         NaN
# 2785             NaN   NaN        NaN        NaN                         NaN
#
#      loan_type                 block_timestamp  loan_id  \
# 2784       NaN  2023-04-28 00:40:35.000000 UTC  34311.0
# 2785       NaN  2023-04-27 13:53:47.000000 UTC  34265.0
#
#                                       to_address  \
# 2784  0xefa755b82218dc287ed37bf6463c144ae6609076
# 2785  0xa35b95b60af5205dbd02571d8d72ef83f79a28af
#
#                                     from_address  principal_amount  \
# 2784  0x08f6db921b10ce9f7ec4166b9be9dc01a30c34cc           10000.0
# 2785  0x1797b4235473fbe0e7e44322f01c1b5618ebda41               6.0
#
#       repayment_amount                               erc20_address erc20_name  \
# 2784      10082.191781  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48       USDc
# 2785          6.540000  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
#
#                             due_date  duration_in_days  apr_y token_id  \
# 2784  2023-05-28 00:40:35.000000 UTC              30.0   0.10     6096
# 2785  2024-04-26 13:53:47.000000 UTC             365.0   0.09     9470
#
#                               collection_address protocol  amt_in_usd  \
# 2784  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi  10000.0000
# 2785  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi  11261.0808
#
#      roll_over  block_number p2p_p2pool loan_id_cleaned      _merge
# 2784     False    17141128.0        p2p           34311  right_only
# 2785     False    17137936.0        p2p           34265  right_only

# %%
pd.set_option('display.float_format', '{:,.0f}'.format)
pd.DataFrame(unique_to_april_nftfi.groupby('loan_contract').agg(sum)['usd_value'])
# Out:
# /tmp/ipykernel_3199236/1441498714.py:2: FutureWarning: The operation <built-in function sum> failed on a column. If any error is raised, this will raise an exception in a future version of pandas. Drop these columns to avoid this warning.
#   pd.DataFrame(unique_to_april_nftfi.groupby('loan_contract').agg(sum)['usd_value'])
#                           usd_value
# loan_contract
# v2-1.loan.fixed           5,254,060
# v2.loan.fixed.collection  8,974,156

# %%
# MQ loans not in NFTfi
# unique_to_april_mq = april_mq[april_mq['loan_id_cleaned'].isin(mq_loans_not_in_nftfi)].reset_index(drop=True)
unique_to_april_mq.head(3)
# Out:
#                                     transaction_hash  \
# 0  0x0f3522aa06eb28b8cceb590ea80cbd335ab64010dab8...
# 1  0xecaf8a9e276b227506ebc8acc837792370ec83d52e39...
# 2  0x2d07d7afcb6324bfc6239c6bcc9bca658a49cd2b227c...
#
#                   block_timestamp  loan_id  \
# 0  2023-04-02 09:27:59.000000 UTC    31180
# 1  2023-04-28 00:40:35.000000 UTC    34311
# 2  2023-04-27 13:53:47.000000 UTC    34265
#
#                                    to_address  \
# 0  0xf7b18e107eb36797f4ce36de756630b9c30969ad
# 1  0xefa755b82218dc287ed37bf6463c144ae6609076
# 2  0xa35b95b60af5205dbd02571d8d72ef83f79a28af
#
#                                  from_address  principal_amount  \
# 0  0x31d75becb2fe9cc60eb4877b44110aa1cdae90a5               800
# 1  0x08f6db921b10ce9f7ec4166b9be9dc01a30c34cc            10,000
# 2  0x1797b4235473fbe0e7e44322f01c1b5618ebda41                 6
#
#    repayment_amount                               erc20_address erc20_name  \
# 0               826  0x6b175474e89094c44da98b954eedeac495271d0f        DAI
# 1            10,082  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48       USDc
# 2                 7  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
#
#                          due_date  duration_in_days  apr_x token_id  \
# 0  2023-06-01 09:27:59.000000 UTC                60      0     2118
# 1  2023-05-28 00:40:35.000000 UTC                30      0     6096
# 2  2024-04-26 13:53:47.000000 UTC               365      0     9470
#
#                            collection_address protocol  amt_in_usd  roll_over  \
# 0  0x026224a2940bfe258d0dbe947919b62fe321f042    nftfi         800      False
# 1  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi      10,000      False
# 2  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi      11,261      False
#
#    block_number p2p_p2pool loan_id_cleaned                loan_no     id  \
# 0      16960517        p2p           31180  v2-1.loan.fixed-31180 31,180
# 1      17141128        p2p           34311                    NaN    NaN
# 2      17137936        p2p           34265                    NaN    NaN
#
#      loan_contract status                                    borrower  \
# 0  v2-1.loan.fixed    NaN  0xF7B18e107eb36797f4cE36dE756630B9C30969ad
# 1              NaN    NaN                                         NaN
# 2              NaN    NaN                                         NaN
#
#                                        lender  loan_principal_amount  \
# 0  0x31d75BeCb2fE9cC60Eb4877B44110aA1CdaE90A5                    800
# 1                                         NaN                    NaN
# 2                                         NaN                    NaN
#
#    maximum_repayment_amount  loan_duration_d  apr_y  \
# 0                         0               30     20
# 1                       NaN              NaN    NaN
# 2                       NaN              NaN    NaN
#
#                 loan_start_time                      date  \
# 0 1970-01-01 00:00:01.680427679 2023-04-02 09:27:59+00:00
# 1                           NaT                       NaT
# 2                           NaT                       NaT
#
#                        loan_erc20denomination  block_num      gas_price  \
# 0  0x6b175474e89094c44da98b954eedeac495271d0f 16,960,517 20,274,855,936
# 1                                         NaN        NaN            NaN
# 2                                         NaN        NaN            NaN
#
#    gas_limit  gas_used  cumulative_gas_used  effective_gas_price repaid  \
# 0    551,203   531,815            4,667,879       20,274,855,936   True
# 1        NaN       NaN                  NaN                  NaN    NaN
# 2        NaN       NaN                  NaN                  NaN    NaN
#
#   liquidated loan_repaid_time repaid_amount_paid_to_lender  \
# 0       True              NaT                          NaN
# 1        NaN              NaT                          NaN
# 2        NaN              NaT                          NaN
#
#   repaid_transaction_hash  repaid_gas_price  repaid_gas_limit  \
# 0                     NaN               NaN               NaN
# 1                     NaN               NaN               NaN
# 2                     NaN               NaN               NaN
#
#    repaid_gas_used  repaid_cumulative_gas_used  repaid_effective_gas_price  \
# 0              NaN                         NaN                         NaN
# 1              NaN                         NaN                         NaN
# 2              NaN                         NaN                         NaN
#
#   repaid_admin_fee loan_liquidation_date liquidated_transaction_hash  \
# 0              NaN                   NaN                         NaN
# 1              NaN                   NaN                         NaN
# 2              NaN                   NaN                         NaN
#
#    liquidated_gas_price  liquidated_gas_limit  liquidated_gas_used  \
# 0                   NaN                   NaN                  NaN
# 1                   NaN                   NaN                  NaN
# 2                   NaN                   NaN                  NaN
#
#    liquidated_cumulative_gas_used  liquidated_effective_gas_price  \
# 0                             NaN                             NaN
# 1                             NaN                             NaN
# 2                             NaN                             NaN
#
#   loan_no_cleaned  high  eth_price  usd_value loan_erc20denomination_name  \
# 0           31180 1,821      1,821        800                         dai
# 1             NaN   NaN        NaN        NaN                         NaN
# 2             NaN   NaN        NaN        NaN                         NaN
#
#          loan_type
# 0  v2-1.loan.fixed
# 1              NaN
# 2              NaN

# %%
# We need to explore this table
unique_to_april_mq.erc20_name.unique()
# Out:
# array(['DAI', 'USDc', 'wETH'], dtype=object)

# %% [markdown]
# ## NFTfi loans not in MQ

# %%
unique_to_april_nftfi
# Out:
#                              loan_no     id             loan_contract  status  \
# 0              v2-1.loan.fixed-31044  31044           v2-1.loan.fixed  repaid
# 1              v2-1.loan.fixed-31045  31045           v2-1.loan.fixed     NaN
# 2     v2.loan.fixed.collection-31046  31046  v2.loan.fixed.collection     NaN
# 3              v2-1.loan.fixed-31047  31047           v2-1.loan.fixed  repaid
# 4     v2.loan.fixed.collection-31048  31048  v2.loan.fixed.collection     NaN
# ...                              ...    ...                       ...     ...
# 2779           v2-1.loan.fixed-33820  33820           v2-1.loan.fixed     NaN
# 2780           v2-1.loan.fixed-33824  33824           v2-1.loan.fixed     NaN
# 2781           v2-1.loan.fixed-33825  33825           v2-1.loan.fixed     NaN
# 2782  v2.loan.fixed.collection-33826  33826  v2.loan.fixed.collection     NaN
# 2783           v2-1.loan.fixed-33827  33827           v2-1.loan.fixed     NaN
#
#                                         borrower  \
# 0     0x371267a1863080c5F39229183350e0D87d39743E
# 1     0x07a2CF3c078D9526Eb50Ba7AFFaBc0049827D126
# 2     0x58463E8ecA64FE736a26d7A2eD95B4Bc6127e268
# 3     0xCd8826a0298cfCd4eeB3a0c118a8aa664316Cd7A
# 4     0x3b7393118f0d8f99f269854CF441A5ebCb0Af246
# ...                                          ...
# 2779  0xBeC69dfcE4c1fA8b7843FEE1Ca85788d84A86B06
# 2780  0x353D1aF0fA732F6230Ff4ab0eB2a6A3Dcf4C54F2
# 2781  0xD758bf1da4B9683454b97988175aa6F9419c2B39
# 2782  0x739dEB8B1232BF13687c0607dd3035E983b3f56F
# 2783  0x887b86B6B6957F7bbeA88B8CEfD392f39236A88C
#
#                                           lender  loan_principal_amount  \
# 0     0x9CD074f0192BB2A477DA3271bA03db4fc5cD38c7                      3
# 1     0x064980edD7D43AbEE781f49A4e31C06Df05EcccB                      0
# 2     0x3e60C12997d3Bb062530e5F7e7f0400FBB9aEcA5                      1
# 3     0xBbB589796d01EF05f24C49f57d53125d4382ab62                      1
# 4     0x591EC71097d9Fda67cF53732239F9591688f37E9                      1
# ...                                          ...                    ...
# 2779  0xc3cea12ffda8B3Dff435155461de6FCc72315117                      0
# 2780  0x1797b4235473fbE0e7e44322F01C1B5618EBda41                      7
# 2781  0x1797b4235473fbE0e7e44322F01C1B5618EBda41                      7
# 2782  0xe9bAB3816a139827fE218D58699097B359680380                      2
# 2783  0x73A1Bb338613291AC6530870Fe2c5D354BFEC17e                      0
#
#       maximum_repayment_amount  loan_duration_d  apr_x  \
# 0                            0               30     40
# 1                            0               30     90
# 2                            0               30     28
# 3                            0                7     55
# 4                            0               30     60
# ...                        ...              ...    ...
# 2779                         0               30     69
# 2780                         0              365      9
# 2781                         0              365      9
# 2782                         0               14     79
# 2783                         0               30     45
#
#                    loan_start_time                      date  \
# 0    1970-01-01 00:00:01.680307511 2023-04-01 00:05:11+00:00
# 1    1970-01-01 00:00:01.680308543 2023-04-01 00:22:23+00:00
# 2    1970-01-01 00:00:01.680310871 2023-04-01 01:01:11+00:00
# 3    1970-01-01 00:00:01.680310979 2023-04-01 01:02:59+00:00
# 4    1970-01-01 00:00:01.680316595 2023-04-01 02:36:35+00:00
# ...                            ...                       ...
# 2779 1970-01-01 00:00:01.682364203 2023-04-24 19:23:23+00:00
# 2780 1970-01-01 00:00:01.682364971 2023-04-24 19:36:11+00:00
# 2781 1970-01-01 00:00:01.682366579 2023-04-24 20:02:59+00:00
# 2782 1970-01-01 00:00:01.682367131 2023-04-24 20:12:11+00:00
# 2783 1970-01-01 00:00:01.682367647 2023-04-24 20:20:47+00:00
#
#                           loan_erc20denomination  block_num  \
# 0     0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950628
# 1     0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950714
# 2     0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950907
# 3     0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950915
# 4     0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16951376
# ...                                          ...        ...
# 2779  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   17118198
# 2780  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   17118262
# 2781  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   17118392
# 2782  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   17118438
# 2783  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48   17118481
#
#                                        transaction_hash    gas_price  \
# 0     0x18c7c39e8fdb35cd976872d05263f92e34d9e8b5825c...  26393453389
# 1     0xa9ba08c02d21f2431178b2daa9edb4e50416948373e8...  21761128223
# 2     0x57bfc3c592f00d6fad19dabbc746cba5ada6d55263bd...  19323776633
# 3     0x6dc7560b2f2d22ad29d1009f2e2c27ff50522d7f0a2a...  19546172958
# 4     0x214898bcb85badfe65864f93faeb933afa8792b23fff...  23602727755
# ...                                                 ...          ...
# 2779  0xd72a47b553f0125bc8ef9ff93fca570d0031a53fe44a...  49000000000
# 2780  0x862834c19fc5e3255d85ee631d45b38c210055fb8aa8...  55983293990
# 2781  0x0f94288dd02f42bb2a38bbacffb8c8d7afa8c7519f8d...  48923952650
# 2782  0x49a1183d64fa141041920c35ee637713bc411390f112...  56169185321
# 2783  0xfd2ae7f526cc0dd5d154e4a24b7d5531201e1b70fab5...  46000000000
#
#       gas_limit  gas_used  cumulative_gas_used  effective_gas_price  repaid  \
# 0        539029    524441              5046898          26393453389    True
# 1        466942    461954              9657250          21761128223    True
# 2        476002    466214             17071471          19323776633    True
# 3        498655    493667              7247311          19546172958    True
# 4        503689    489101             10647808          23602727755    True
# ...         ...       ...                  ...                  ...     ...
# 2779     470680    465692              6148167          49000000000    True
# 2780     528871    509483              9778066          55983293990    True
# 2781     528891    509503             16206666          48923952650    True
# 2782     512105    502317             12210820          56169185321    True
# 2783     490745    480957              6695289          46000000000    True
#
#       liquidated          loan_repaid_time repaid_amount_paid_to_lender  \
# 0           True 2023-04-24 09:17:59+00:00          2681185100000000000
# 1           True                       NaT                          NaN
# 2           True                       NaT                          NaN
# 3           True 2023-04-14 22:58:23+00:00          1224049250000000000
# 4           True                       NaT                          NaN
# ...          ...                       ...                          ...
# 2779        True                       NaT                          NaN
# 2780        True                       NaT                          NaN
# 2781        True                       NaT                          NaN
# 2782        True                       NaT                          NaN
# 2783        True                       NaT                          NaN
#
#                                 repaid_transaction_hash  repaid_gas_price  \
# 0     0xb0ca08e743122d22d09806ba5850cda85f605dee5bfc...    38,753,230,709
# 1                                                   NaN               NaN
# 2                                                   NaN               NaN
# 3     0x11869c955df36d7cbca9e01418f775bcf9ff363741de...    27,869,791,665
# 4                                                   NaN               NaN
# ...                                                 ...               ...
# 2779                                                NaN               NaN
# 2780                                                NaN               NaN
# 2781                                                NaN               NaN
# 2782                                                NaN               NaN
# 2783                                                NaN               NaN
#
#       repaid_gas_limit  repaid_gas_used  repaid_cumulative_gas_used  \
# 0              454,254          240,516                   2,481,228
# 1                  NaN              NaN                         NaN
# 2                  NaN              NaN                         NaN
# 3              406,804          215,209                     992,838
# 4                  NaN              NaN                         NaN
# ...                ...              ...                         ...
# 2779               NaN              NaN                         NaN
# 2780               NaN              NaN                         NaN
# 2781               NaN              NaN                         NaN
# 2782               NaN              NaN                         NaN
# 2783               NaN              NaN                         NaN
#
#       repaid_effective_gas_price  repaid_admin_fee loan_liquidation_date  \
# 0                 38,753,230,709  4272900000000000                   NaN
# 1                            NaN               NaN                   NaN
# 2                            NaN               NaN                   NaN
# 3                 27,869,791,665  1265750000000000                   NaN
# 4                            NaN               NaN                   NaN
# ...                          ...               ...                   ...
# 2779                         NaN               NaN                   NaN
# 2780                         NaN               NaN                   NaN
# 2781                         NaN               NaN                   NaN
# 2782                         NaN               NaN                   NaN
# 2783                         NaN               NaN                   NaN
#
#      liquidated_transaction_hash  liquidated_gas_price  liquidated_gas_limit  \
# 0                            NaN                   NaN                   NaN
# 1                            NaN                   NaN                   NaN
# 2                            NaN                   NaN                   NaN
# 3                            NaN                   NaN                   NaN
# 4                            NaN                   NaN                   NaN
# ...                          ...                   ...                   ...
# 2779                         NaN                   NaN                   NaN
# 2780                         NaN                   NaN                   NaN
# 2781                         NaN                   NaN                   NaN
# 2782                         NaN                   NaN                   NaN
# 2783                         NaN                   NaN                   NaN
#
#       liquidated_gas_used  liquidated_cumulative_gas_used  \
# 0                     NaN                             NaN
# 1                     NaN                             NaN
# 2                     NaN                             NaN
# 3                     NaN                             NaN
# 4                     NaN                             NaN
# ...                   ...                             ...
# 2779                  NaN                             NaN
# 2780                  NaN                             NaN
# 2781                  NaN                             NaN
# 2782                  NaN                             NaN
# 2783                  NaN                             NaN
#
#       liquidated_effective_gas_price loan_no_cleaned  high  eth_price  \
# 0                                NaN           31044 1,824      1,823
# 1                                NaN           31045 1,828      1,826
# 2                                NaN           31046 1,822      1,822
# 3                                NaN           31047 1,822      1,822
# 4                                NaN           31048 1,828      1,825
# ...                              ...             ...   ...        ...
# 2779                             NaN           33820 1,831      1,829
# 2780                             NaN           33824 1,833      1,832
# 2781                             NaN           33825 1,836      1,836
# 2782                             NaN           33826 1,839      1,838
# 2783                             NaN           33827 1,842      1,840
#
#       usd_value loan_erc20denomination_name                 loan_type  \
# 0         4,741                        weth           v2-1.loan.fixed
# 1           685                        weth           v2-1.loan.fixed
# 2         1,250                        weth  v2.loan.fixed.collection
# 3         2,186                        weth           v2-1.loan.fixed
# 4         1,642                        weth  v2.loan.fixed.collection
# ...         ...                         ...                       ...
# 2779        915                        weth           v2-1.loan.fixed
# 2780     12,824                        weth           v2-1.loan.fixed
# 2781     12,851                        weth           v2-1.loan.fixed
# 2782      4,137                        weth  v2.loan.fixed.collection
# 2783          0                        usdc           v2-1.loan.fixed
#
#                      block_timestamp  loan_id  \
# 0     2023-04-01 00:05:11.000000 UTC   31,044
# 1                                NaN      NaN
# 2                                NaN      NaN
# 3     2023-04-01 01:02:59.000000 UTC   31,047
# 4                                NaN      NaN
# ...                              ...      ...
# 2779                             NaN      NaN
# 2780  2023-04-24 19:36:11.000000 UTC   33,824
# 2781  2023-04-24 20:02:59.000000 UTC   33,825
# 2782                             NaN      NaN
# 2783                             NaN      NaN
#
#                                       to_address  \
# 0     0x371267a1863080c5f39229183350e0d87d39743e
# 1                                            NaN
# 2                                            NaN
# 3     0xcd8826a0298cfcd4eeb3a0c118a8aa664316cd7a
# 4                                            NaN
# ...                                          ...
# 2779                                         NaN
# 2780  0x353d1af0fa732f6230ff4ab0eb2a6a3dcf4c54f2
# 2781  0xd758bf1da4b9683454b97988175aa6f9419c2b39
# 2782                                         NaN
# 2783                                         NaN
#
#                                     from_address  principal_amount  \
# 0     0x9cd074f0192bb2a477da3271ba03db4fc5cd38c7                 3
# 1                                            NaN               NaN
# 2                                            NaN               NaN
# 3     0xbbb589796d01ef05f24c49f57d53125d4382ab62                 1
# 4                                            NaN               NaN
# ...                                          ...               ...
# 2779                                         NaN               NaN
# 2780  0x1797b4235473fbe0e7e44322f01c1b5618ebda41                 7
# 2781  0x1797b4235473fbe0e7e44322f01c1b5618ebda41                 7
# 2782                                         NaN               NaN
# 2783                                         NaN               NaN
#
#       repayment_amount                               erc20_address erc20_name  \
# 0                    3  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 1                  NaN                                         NaN        NaN
# 2                  NaN                                         NaN        NaN
# 3                    1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 4                  NaN                                         NaN        NaN
# ...                ...                                         ...        ...
# 2779               NaN                                         NaN        NaN
# 2780                 8  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 2781                 8  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2       wETH
# 2782               NaN                                         NaN        NaN
# 2783               NaN                                         NaN        NaN
#
#                             due_date  duration_in_days  apr_y token_id  \
# 0     2023-05-01 00:05:11.000000 UTC                30      0    17119
# 1                                NaN               NaN    NaN      NaN
# 2                                NaN               NaN    NaN      NaN
# 3     2023-04-15 01:02:59.000000 UTC                14      1     9517
# 4                                NaN               NaN    NaN      NaN
# ...                              ...               ...    ...      ...
# 2779                             NaN               NaN    NaN      NaN
# 2780  2024-04-23 19:36:11.000000 UTC               365      0     3903
# 2781  2024-04-23 20:02:59.000000 UTC               365      0      795
# 2782                             NaN               NaN    NaN      NaN
# 2783                             NaN               NaN    NaN      NaN
#
#                               collection_address protocol  amt_in_usd  \
# 0     0x49cf6f5d44e70224e2e23fdcdd2c053f30ada28b    nftfi       4,737
# 1                                            NaN      NaN         NaN
# 2                                            NaN      NaN         NaN
# 3     0x5946aeaab44e65eb370ffaa6a7ef2218cff9b47d    nftfi       2,188
# 4                                            NaN      NaN         NaN
# ...                                          ...      ...         ...
# 2779                                         NaN      NaN         NaN
# 2780  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi      12,821
# 2781  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi      12,819
# 2782                                         NaN      NaN         NaN
# 2783                                         NaN      NaN         NaN
#
#      roll_over  block_number p2p_p2pool loan_id_cleaned
# 0        False    16,950,628        p2p           31044
# 1          NaN           NaN        NaN             NaN
# 2          NaN           NaN        NaN             NaN
# 3        False    16,950,915        p2p           31047
# 4          NaN           NaN        NaN             NaN
# ...        ...           ...        ...             ...
# 2779       NaN           NaN        NaN             NaN
# 2780     False    17,118,262        p2p           33824
# 2781     False    17,118,392        p2p           33825
# 2782       NaN           NaN        NaN             NaN
# 2783       NaN           NaN        NaN             NaN
#
# [2784 rows x 63 columns]

# %%
# Explore the resulting set of unique_to_april_nftfi. Is there any pattern?
unique_to_april_nftfi.describe()
# Out:
#           id  loan_principal_amount  maximum_repayment_amount  \
# count  2,784                  2,784                     2,784
# mean  32,436                  1,206                         0
# std      804                  7,437                         0
# min   31,044                      0                         0
# 25%   31,740                      0                         0
# 50%   32,436                      1                         0
# 75%   33,131                      3                         0
# max   33,827                 65,000                         0
#
#        loan_duration_d  apr_x  block_num       gas_price  gas_limit  gas_used  \
# count            2,784  2,784      2,784           2,784      2,784     2,784
# mean                29     52 17,032,597  30,576,111,122    501,913   486,009
# std                 39     35     46,747  12,923,017,372     68,596    29,331
# min                  1      0 16,950,628  15,840,527,982    449,404   439,616
# 25%                 14     29 16,992,504  21,577,190,703    470,481   463,202
# 50%                 30     49 17,029,126  26,114,680,192    494,964   485,078
# 75%                 30     70 17,069,743  35,817,050,548    522,432   507,749
# max                371    299 17,118,481 111,844,547,450  2,127,032   624,659
#
#        cumulative_gas_used  effective_gas_price  repaid_gas_price  \
# count                2,784                2,784               494
# mean            11,214,634       30,576,111,122    34,669,794,963
# std              5,761,207       12,923,017,372    15,000,096,631
# min                474,677       15,840,527,982    18,825,273,282
# 25%              7,437,193       21,577,190,703    24,210,609,004
# 50%             10,221,288       26,114,680,192    29,000,000,000
# 75%             13,740,146       35,817,050,548    39,809,426,483
# max             29,910,369      111,844,547,450    98,131,606,435
#
#        repaid_gas_limit  repaid_gas_used  repaid_cumulative_gas_used  \
# count               494              494                         494
# mean            409,011          216,708                   6,353,557
# std              49,175           21,792                   6,073,457
# min             266,788          185,436                     348,367
# 25%             375,816          199,394                   2,204,403
# 50%             392,698          208,591                   3,898,013
# 75%             439,932          232,878                   8,496,101
# max             957,728          335,420                  29,181,971
#
#        repaid_effective_gas_price  liquidated_gas_price  liquidated_gas_limit  \
# count                         494                   265                   265
# mean               34,669,794,963        45,402,104,291               517,582
# std                15,000,096,631        12,516,144,261               951,731
# min                18,825,273,282        19,116,326,214               202,882
# 25%                24,210,609,004        37,307,097,371               304,323
# 50%                29,000,000,000        45,560,881,573               304,323
# 75%                39,809,426,483        54,946,767,423               370,306
# max                98,131,606,435        91,057,207,396             5,300,000
#
#        liquidated_gas_used  liquidated_cumulative_gas_used  \
# count                  265                             265
# mean               179,911                       6,360,596
# std                 31,950                       4,368,854
# min                160,556                         566,241
# 25%                160,556                       3,691,044
# 50%                160,556                       5,131,213
# 75%                195,747                       7,715,615
# max                312,532                      26,794,702
#
#        liquidated_effective_gas_price  high  eth_price  usd_value  loan_id  \
# count                             265 2,784      2,784      2,784    1,422
# mean                   45,402,104,291 1,927      1,926      6,856   32,433
# std                    12,516,144,261   101        101     18,951      827
# min                    19,116,326,214 1,776      1,775          0   31,044
# 25%                    37,307,097,371 1,857      1,856        778   31,745
# 50%                    45,560,881,573 1,892      1,891      1,419   32,364
# 75%                    54,946,767,423 1,985      1,983      4,009   33,188
# max                    91,057,207,396 2,133      2,133    360,029   33,825
#
#        principal_amount  repayment_amount  duration_in_days  apr_y  \
# count             1,422             1,422             1,422  1,422
# mean                289               298                33      0
# std               1,736             1,793                52      0
# min                   0                 0                 3      0
# 25%                   0                 0                14      0
# 50%                   1                 1                30      0
# 75%                   2                 2                30      1
# max              35,000            36,392               371      3
#
#        amt_in_usd  block_number
# count       1,422         1,422
# mean        3,471    17,032,664
# std         5,434        48,343
# min            18    16,950,628
# 25%           765    16,992,636
# 50%         1,657    17,025,498
# 75%         2,999    17,074,250
# max        76,639    17,118,392

# %% [markdown]
# ### Are discrepancies due to loan type which is not accounted for?

# %%
# How about loan numbers, how do they vary from a naming standpoint?
# x[0]+x[1] if len(x) >2 else x[0] is such that it returns "v2-1.loan.fixed" from "v2-1.loan.fixed-32381", 
#    else returns "v2.loan.fixed.collection" from "v2.loan.fixed.collection-34479"

unique_to_april_nftfi.loan_no.astype(str).str.split('-').apply(lambda x: x[0]+'-'+x[1] if len(x) >2 else x[0]).unique()
# it seems from the above result that [v2-1.loan.fixed', 'v2.loan.fixed.collection'] are the two loan types which are not accounted for
# Out:
# array(['v2-1.loan.fixed', 'v2.loan.fixed.collection'], dtype=object)

# %%
# Is the above true as well for the whole table set?
nftfi_loans_not_in_mq = list(
        set(list(nftfi.loan_no_cleaned)) - set(list(mq.loan_id_cleaned))
    )
print(len(nftfi_loans_not_in_mq))
# How about loan numbers, how do they vary from a naming standpoint?
# x[0]+x[1] if len(x) >2 else x[0] is such that it returns "v2-1.loan.fixed" from "v2-1.loan.fixed-32381", 
#    else returns "v2.loan.fixed.collection" from "v2.loan.fixed.collection-34479"

unique_to_april_nftfi.loan_no.astype(str).str.split('-').apply(lambda x: x[0]+'-'+x[1] if len(x) >2 else x[0]).unique()
# it seems from the above result that [v2-1.loan.fixed', 'v2.loan.fixed.collection'] are the two loan types which are not accounted for
# Out:
# 14989
# array(['v2-1.loan.fixed', 'v2.loan.fixed.collection'], dtype=object)

# %% [markdown]
# ### Is it due to missed erc20 token denomination?

# %%
# Check if it can be due to missing token
usdc_address = '0xA0b86991c6218b36c1d19D4a2e9Eb0cE3606eB48'  # https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48
usdt_address = '0xdAC17F958D2ee523a2206206994597C13D831ec7'  # https://etherscan.io/token/0xdac17f958d2ee523a2206206994597c13d831ec7
dai_address = '0x6B175474E89094C44Da98b954EedeAC495271d0F'  # https://etherscan.io/token/0x6b175474e89094c44da98b954eedeac495271d0f
weth_address = '0xC02aaA39b223FE8D0A0e5C4F27eAD9083C756Cc2'

stablecoin_addresses = [usdc_address, usdt_address, dai_address, weth_address]

stablecoin_names = ['usdc', 'usdt', 'dai', 'weth']
for stablecoin_address, stablecoin_name in zip(stablecoin_addresses, stablecoin_names):
    stablecoin_address = stablecoin_address.lower()
    unique_to_april_nftfi.loc[unique_to_april_nftfi['loan_erc20denomination'] == stablecoin_address, 'loan_erc20denomination_name'] = stablecoin_name

# %%
unique_to_april_nftfi.loan_erc20denomination_name.unique()
# It does not seem to be linked to missing token.
# Out:
# array(['weth', 'usdc', 'dai'], dtype=object)

# %% [markdown]
# ### Let's compute loan volumes per token denomination to see if they match

# %%
display(april_nftfi.head(2))
display(april_mq.head(2))
# Out:
#                      loan_no     id    loan_contract  status  \
# 37971  v2-1.loan.fixed-31044  31044  v2-1.loan.fixed  repaid
# 37972  v2-1.loan.fixed-31045  31045  v2-1.loan.fixed     NaN
#
#                                          borrower  \
# 37971  0x371267a1863080c5F39229183350e0D87d39743E
# 37972  0x07a2CF3c078D9526Eb50Ba7AFFaBc0049827D126
#
#                                            lender  loan_principal_amount  \
# 37971  0x9CD074f0192BB2A477DA3271bA03db4fc5cD38c7                      3
# 37972  0x064980edD7D43AbEE781f49A4e31C06Df05EcccB                      0
#
#        maximum_repayment_amount  loan_duration_d  apr  \
# 37971                         0               30   40
# 37972                         0               30   90
#
#                     loan_start_time                      date  \
# 37971 1970-01-01 00:00:01.680307511 2023-04-01 00:05:11+00:00
# 37972 1970-01-01 00:00:01.680308543 2023-04-01 00:22:23+00:00
#
#                            loan_erc20denomination  block_num  \
# 37971  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950628
# 37972  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2   16950714
#
#                                         transaction_hash    gas_price  \
# 37971  0x18c7c39e8fdb35cd976872d05263f92e34d9e8b5825c...  26393453389
# 37972  0xa9ba08c02d21f2431178b2daa9edb4e50416948373e8...  21761128223
#
#        gas_limit  gas_used  cumulative_gas_used  effective_gas_price  repaid  \
# 37971     539029    524441              5046898          26393453389    True
# 37972     466942    461954              9657250          21761128223    True
#
#        liquidated          loan_repaid_time repaid_amount_paid_to_lender  \
# 37971        True 2023-04-24 09:17:59+00:00          2681185100000000000
# 37972        True                       NaT                          NaN
#
#                                  repaid_transaction_hash  repaid_gas_price  \
# 37971  0xb0ca08e743122d22d09806ba5850cda85f605dee5bfc...    38,753,230,709
# 37972                                                NaN               NaN
#
#        repaid_gas_limit  repaid_gas_used  repaid_cumulative_gas_used  \
# 37971           454,254          240,516                   2,481,228
# 37972               NaN              NaN                         NaN
#
#        repaid_effective_gas_price  repaid_admin_fee loan_liquidation_date  \
# 37971              38,753,230,709  4272900000000000                   NaN
# 37972                         NaN               NaN                   NaN
#
#       liquidated_transaction_hash  liquidated_gas_price  liquidated_gas_limit  \
# 37971                         NaN                   NaN                   NaN
# 37972                         NaN                   NaN                   NaN
#
#        liquidated_gas_used  liquidated_cumulative_gas_used  \
# 37971                  NaN                             NaN
# 37972                  NaN                             NaN
#
#        liquidated_effective_gas_price loan_no_cleaned  high  eth_price  \
# 37971                             NaN           31044 1,824      1,823
# 37972                             NaN           31045 1,828      1,826
#
#        usd_value loan_erc20denomination_name        loan_type
# 37971      4,741                        weth  v2-1.loan.fixed
# 37972        685                        weth  v2-1.loan.fixed
#                                      transaction_hash  \
# 2   0x0f3522aa06eb28b8cceb590ea80cbd335ab64010dab8...
# 28  0xecaf8a9e276b227506ebc8acc837792370ec83d52e39...
#
#                    block_timestamp  loan_id  \
# 2   2023-04-02 09:27:59.000000 UTC    31180
# 28  2023-04-28 00:40:35.000000 UTC    34311
#
#                                     to_address  \
# 2   0xf7b18e107eb36797f4ce36de756630b9c30969ad
# 28  0xefa755b82218dc287ed37bf6463c144ae6609076
#
#                                   from_address  principal_amount  \
# 2   0x31d75becb2fe9cc60eb4877b44110aa1cdae90a5               800
# 28  0x08f6db921b10ce9f7ec4166b9be9dc01a30c34cc            10,000
#
#     repayment_amount                               erc20_address erc20_name  \
# 2                826  0x6b175474e89094c44da98b954eedeac495271d0f        DAI
# 28            10,082  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48       USDc
#
#                           due_date  duration_in_days  apr token_id  \
# 2   2023-06-01 09:27:59.000000 UTC                60    0     2118
# 28  2023-05-28 00:40:35.000000 UTC                30    0     6096
#
#                             collection_address protocol  amt_in_usd  \
# 2   0x026224a2940bfe258d0dbe947919b62fe321f042    nftfi         800
# 28  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a    nftfi      10,000
#
#     roll_over  block_number p2p_p2pool loan_id_cleaned
# 2       False      16960517        p2p           31180
# 28      False      17141128        p2p           34311

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.float_format', '{:,.2f}'.format)
display(april_nftfi.groupby('loan_erc20denomination_name').agg('sum'))

display(april_mq.groupby('erc20_name').agg('sum'))
# Out:
#                                    id  loan_principal_amount  \
# loan_erc20denomination_name
# dai                           6594977           3,350,375.71
# usdc                          2453169                   0.00
# weth                         81252286               8,183.79
#
#                              maximum_repayment_amount  loan_duration_d  \
# loan_erc20denomination_name
# dai                                              0.00             5968
# usdc                                             0.00             2640
# weth                                             0.00            72342
#
#                                    apr    block_num       gas_price  \
# loan_erc20denomination_name
# dai                           6,054.41   3458304699   6832966278316
# usdc                          3,896.08   1278656120   2807403673316
# weth                        135,582.41  42681789444  75483523412806
#
#                               gas_limit    gas_used  cumulative_gas_used  \
# loan_erc20denomination_name
# dai                           103456648   100375684           2353757822
# usdc                           39417988    38646194            991095083
# weth                         1254451253  1214026491          27876688741
#
#                              effective_gas_price  repaid  liquidated  \
# loan_erc20denomination_name
# dai                                6832966278316     203         203
# usdc                               2807403673316      75          75
# weth                              75483523412806    2506        2506
#
#                                  repaid_gas_price  repaid_gas_limit  \
# loan_erc20denomination_name
# dai                            769,162,008,701.00     10,835,521.00
# usdc                           186,589,305,863.00      2,599,827.00
# weth                        16,171,127,396,980.00    188,615,897.00
#
#                              repaid_gas_used  repaid_cumulative_gas_used  \
# loan_erc20denomination_name
# dai                             5,725,645.00              190,423,346.00
# usdc                            1,376,511.00               40,229,807.00
# weth                           99,951,744.00            2,908,004,194.00
#
#                              repaid_effective_gas_price  liquidated_gas_price  \
# loan_erc20denomination_name
# dai                                  769,162,008,701.00     21,235,263,805.00
# usdc                                 186,589,305,863.00                  0.00
# weth                              16,171,127,396,980.00 12,010,322,373,414.00
#
#                              liquidated_gas_limit  liquidated_gas_used  \
# loan_erc20denomination_name
# dai                                    335,454.00           177,159.00
# usdc                                         0.00                 0.00
# weth                               136,823,706.00        47,499,156.00
#
#                              liquidated_cumulative_gas_used  \
# loan_erc20denomination_name
# dai                                            6,848,085.00
# usdc                                                   0.00
# weth                                       1,678,709,938.00
#
#                              liquidated_effective_gas_price         high  \
# loan_erc20denomination_name
# dai                                       21,235,263,805.00   390,801.69
# usdc                                                   0.00   146,504.09
# weth                                  12,010,322,373,414.00 4,828,052.68
#
#                                eth_price     usd_value
# loan_erc20denomination_name
# dai                           390,569.03  3,350,375.71
# usdc                          146,396.44          0.00
# weth                        4,825,026.23 15,736,525.80
#              loan_id  principal_amount  repayment_amount  duration_in_days  \
# erc20_name
# DAI          4191128        394,685.88        405,500.21          3,675.00
# USDc         1978300        451,556.00        456,643.87          1,653.00
# wETH        54665173          2,977.71          3,074.87         54,582.00
#
#               apr   amt_in_usd  roll_over  block_number
# erc20_name
# DAI         42.73   394,685.88          0    2182533702
# USDc        22.86   451,556.00          0    1008723705
# wETH       812.65 5,676,459.91          0   28398510161

# %%
print("NFTfi:")
display(pd.DataFrame(april_nftfi.groupby('loan_erc20denomination_name').agg('sum')['loan_principal_amount']))
print("\n\nMQ:")
display(pd.DataFrame(april_mq.groupby('erc20_name').agg('sum')['principal_amount']))
# Out:
# NFTfi:
#                              loan_principal_amount
# loan_erc20denomination_name
# dai                                   3,350,375.71
# usdc                                          0.00
# weth                                      8,183.79
# MQ:
#             principal_amount
# erc20_name
# DAI               394,685.88
# USDc              451,556.00
# wETH                2,977.71

# %% [markdown]
# #### We see from the above results that NFTfi and MQ respective loan principal amounts grouped by the loan erc20 denomination do not match at all. How about the total dollar numbers?

# %%
print("NFTfi:")
total_usd_nftfi_volume_per_ccy = pd.DataFrame(april_nftfi.groupby('loan_erc20denomination_name').agg('sum')['usd_value'])
display(total_usd_nftfi_volume_per_ccy)
print("\n\nMQ:")
total_usd_mq_volume_per_ccy = pd.DataFrame(april_mq.groupby('erc20_name').agg('sum')['amt_in_usd'])
display(total_usd_mq_volume_per_ccy)
# Out:
# NFTfi:
#                                 usd_value
# loan_erc20denomination_name
# dai                          3,350,375.71
# usdc                                 0.00
# weth                        15,736,525.80
# MQ:
#              amt_in_usd
# erc20_name
# DAI          394,685.88
# USDc         451,556.00
# wETH       5,676,459.91

# %% [markdown]
# #### Total numbers are very off. Can that be explained with the set of loans which are not in each dataset?

# %%
print("Total dollar value of loan principal for NFTfi loans which are not in MQ, for April and NFTfi:")
display(pd.DataFrame(unique_to_april_nftfi.groupby('loan_erc20denomination_name').agg('sum')['usd_value']))
print("\n\nTotal dollar value of loan principal for MQ loans which are not inNFtfi, for April and MQ:")
display(pd.DataFrame(unique_to_april_mq.groupby('erc20_name').agg('sum')['amt_in_usd']))
# Out:
# Total dollar value of loan principal for NFTfi loans which are not in MQ, for April and NFTfi:
#                                 usd_value
# loan_erc20denomination_name
# dai                          3,350,375.71
# usdc                                 0.00
# weth                        15,736,525.80
# Total dollar value of loan principal for MQ loans which are not inNFtfi, for April and MQ:
#              amt_in_usd
# erc20_name
# DAI          394,685.88
# USDc         451,556.00
# wETH       5,676,459.91

# %%
usd_values_of_nftfi_not_in_mq = pd.DataFrame(unique_to_april_nftfi.groupby('loan_erc20denomination_name').agg('sum')['usd_value'])
usd_values_of_mq_not_in_nftfi = pd.DataFrame(unique_to_april_mq.groupby('erc20_name').agg('sum')['amt_in_usd'])

# %%
weth_usd_amount_nftfi_not_in_mq = usd_values_of_nftfi_not_in_mq.loc['weth'].values[0]
weth_usd_amount_mq_not_in_nftfi = usd_values_of_mq_not_in_nftfi.loc['wETH'].values[0]

weth_usd_amount_total_nftfi = total_usd_nftfi_volume_per_ccy.loc['weth'].values[0]
weth_usd_amount_total_mq = total_usd_mq_volume_per_ccy.loc['wETH'].values[0]

print(weth_usd_amount_total_nftfi, weth_usd_amount_nftfi_not_in_mq, weth_usd_amount_mq_not_in_nftfi, weth_usd_amount_total_mq)

# total NFTfi missing from MQ volume, minus total MQ volume missing from NFTfi

weth_usd_amount_nftfi_not_in_mq - weth_usd_amount_mq_not_in_nftfi - weth_usd_amount_total_nftfi  + weth_usd_amount_total_mq
# Out:
# 15736525.796682782 15736525.796682782 5676459.911920467 5676459.911920467
# 0.0

# %% [markdown]
# #### How about dollar amounts PER loan type PER ccy?

# %%
usd_values_of_nftfi_not_in_mq = pd.DataFrame(unique_to_april_nftfi.groupby(['loan_erc20denomination_name','loan_type']).agg('sum')['usd_value'])
usd_values_of_nftfi_not_in_mq
# Out:
#                                                         usd_value
# loan_erc20denomination_name loan_type
# dai                         v2-1.loan.fixed          1,133,987.41
#                             v2.loan.fixed.collection 2,216,388.29
# usdc                        v2-1.loan.fixed                  0.00
#                             v2.loan.fixed.collection         0.00
# weth                        v2-1.loan.fixed          6,656,293.63
#                             v2.loan.fixed.collection 9,080,232.17

# %%
print("NFTfi:")
display(total_usd_nftfi_volume_per_ccy)
print("\n\nMQ:")
display(total_usd_mq_volume_per_ccy)
# Out:
# NFTfi:
#                                 usd_value
# loan_erc20denomination_name
# dai                          3,350,375.71
# usdc                                 0.00
# weth                        15,736,525.80
# MQ:
#              amt_in_usd
# erc20_name
# DAI          394,685.88
# USDc         451,556.00
# wETH       5,676,459.91

# %% [markdown]
# ## For the loan IDs which do match... are they the same loans?

# %%
import copy
nftfi_with_col_prefix = copy.deepcopy(nftfi)
mq_with_col_prefix = copy.deepcopy(mq)
nftfi_with_col_prefix = nftfi_with_col_prefix.rename(columns={col: 'nftfi_'+ col for col in nftfi.columns})
mq_with_col_prefix = mq_with_col_prefix.rename(columns={col: 'mq_'+ col for col in mq.columns})

matching_mq_with_nftfi = pd.merge(left=nftfi_with_col_prefix, right=mq_with_col_prefix, left_on='nftfi_loan_no_cleaned', right_on='mq_loan_id_cleaned', how='inner', suffixes=('nftfi', 'mq'))
matching_mq_with_nftfi
# Out:
#                nftfi_loan_no  nftfi_id nftfi_loan_contract nftfi_status  \
# 0            v1.loan.fixed-1         1       v1.loan.fixed       repaid
# 1            v2.loan.fixed-1         1       v2.loan.fixed       repaid
# 2            v1.loan.fixed-2         2       v1.loan.fixed       repaid
# 3            v2.loan.fixed-2         2       v2.loan.fixed       repaid
# 4            v1.loan.fixed-3         3       v1.loan.fixed       repaid
# ...                      ...       ...                 ...          ...
# 28024  v2-1.loan.fixed-33808     33808     v2-1.loan.fixed          NaN
# 28025  v2-1.loan.fixed-33809     33809     v2-1.loan.fixed          NaN
# 28026  v2-1.loan.fixed-33810     33810     v2-1.loan.fixed          NaN
# 28027  v2-1.loan.fixed-33824     33824     v2-1.loan.fixed          NaN
# 28028  v2-1.loan.fixed-33825     33825     v2-1.loan.fixed          NaN
#
#                                    nftfi_borrower  \
# 0      0xc35A5FEc6BE6957899E15559Be252Db882220b37
# 1      0x3e3B47b5d433bE4708A6BD524faCd48Bb54D10b1
# 2      0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe
# 3      0x3e3B47b5d433bE4708A6BD524faCd48Bb54D10b1
# 4      0xc35A5FEc6BE6957899E15559Be252Db882220b37
# ...                                           ...
# 28024  0xB2A2a6a69E7A0aD66943F4c2869d45A9919CF740
# 28025  0xB2A2a6a69E7A0aD66943F4c2869d45A9919CF740
# 28026  0xB2A2a6a69E7A0aD66943F4c2869d45A9919CF740
# 28027  0x353D1aF0fA732F6230Ff4ab0eB2a6A3Dcf4C54F2
# 28028  0xD758bf1da4B9683454b97988175aa6F9419c2B39
#
#                                      nftfi_lender  \
# 0      0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe
# 1      0xd79275564CCAd8E679cbBb5E1C2FaCD46643a372
# 2      0xc35A5FEc6BE6957899E15559Be252Db882220b37
# 3      0xd79275564CCAd8E679cbBb5E1C2FaCD46643a372
# 4      0x44DdF3e35Cd2D629d78674FF6BF5b953e2B069fe
# ...                                           ...
# 28024  0xF4Fb9FA23edB32215E5284cf7dBfDB5607d51a5b
# 28025  0xF4Fb9FA23edB32215E5284cf7dBfDB5607d51a5b
# 28026  0xF4Fb9FA23edB32215E5284cf7dBfDB5607d51a5b
# 28027  0x1797b4235473fbE0e7e44322F01C1B5618EBda41
# 28028  0x1797b4235473fbE0e7e44322F01C1B5618EBda41
#
#        nftfi_loan_principal_amount  nftfi_maximum_repayment_amount  \
# 0                             0.00                            0.00
# 1                             0.01                            0.00
# 2                             0.03                            0.00
# 3                             0.01                            0.00
# 4                             0.00                            0.00
# ...                            ...                             ...
# 28024                         1.25                            0.00
# 28025                         1.20                            0.00
# 28026                         1.20                            0.00
# 28027                         7.00                            0.00
# 28028                         7.00                            0.00
#
#        nftfi_loan_duration_d  nftfi_apr         nftfi_loan_start_time  \
# 0                          7     173.81 1970-01-01 00:00:01.589623507
# 1                         14       9.91 1970-01-01 00:00:01.648635692
# 2                          7      17.38 1970-01-01 00:00:01.589628655
# 3                         14       9.91 1970-01-01 00:00:01.648636560
# 4                          7      17.38 1970-01-01 00:00:01.589631935
# ...                      ...        ...                           ...
# 28024                     60      39.00 1970-01-01 00:00:01.682357939
# 28025                     60      39.00 1970-01-01 00:00:01.682358287
# 28026                     60      39.00 1970-01-01 00:00:01.682358299
# 28027                    365       9.00 1970-01-01 00:00:01.682364971
# 28028                    365       9.00 1970-01-01 00:00:01.682366579
#
#                      nftfi_date                nftfi_loan_erc20denomination  \
# 0     2020-05-16 10:05:07+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1     2022-03-30 10:21:32+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2     2020-05-16 11:30:55+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3     2022-03-30 10:36:00+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4     2020-05-16 12:25:35+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ...                         ...                                         ...
# 28024 2023-04-24 17:38:59+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28025 2023-04-24 17:44:47+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28026 2023-04-24 17:44:59+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28027 2023-04-24 19:36:11+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28028 2023-04-24 20:02:59+00:00  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#        nftfi_block_num                             nftfi_transaction_hash  \
# 0             10076484  0x937a5320404c0c835f2739c84b229ef837a9f0b0ef92...
# 1             14487024  0x166d57a868ae6c3e34c192546aedc243eda0c7ba6685...
# 2             10076867  0xf331e9fb8341f1b644e0edfe599a56402836808b2570...
# 3             14487091  0x9d783e3bbde1663ffa2dcc0bf5eabeccbe3f58475938...
# 4             10077100  0x330e8f56d4f6eb07392d8c23858eda1cada42c550ed9...
# ...                ...                                                ...
# 28024         17117683  0x2573d462a1e5bc8c7085f18a317dee42c6003e86e40b...
# 28025         17117712  0x182b91443edf0fdcdf9210e2792a1475d6c47f9e8175...
# 28026         17117713  0x97b46e05a3d4e573b0cd59df2657c5478081e6a4d12f...
# 28027         17118262  0x862834c19fc5e3255d85ee631d45b38c210055fb8aa8...
# 28028         17118392  0x0f94288dd02f42bb2a38bbacffb8c8d7afa8c7519f8d...
#
#        nftfi_gas_price  nftfi_gas_limit  nftfi_gas_used  \
# 0          19755020080           500000          441106
# 1          33892599088           840378          540864
# 2          12100000000           500000          403060
# 3          24769994524           757849          490645
# 4          15430188679           500000          428215
# ...                ...              ...             ...
# 28024      60758034730           533673          514285
# 28025      51243960438           543473          528885
# 28026      55397766781           533653          514265
# 28027      55983293990           528871          509483
# 28028      48923952650           528891          509503
#
#        nftfi_cumulative_gas_used  nftfi_effective_gas_price  nftfi_repaid  \
# 0                        9710213                19755020080          True
# 1                        5140379                33892599088          True
# 2                        9269753                12100000000          True
# 3                        7281728                24769994524          True
# 4                        2708977                15430188679          True
# ...                          ...                        ...           ...
# 28024                   11129095                60758034730          True
# 28025                   18678811                51243960438          True
# 28026                    6290372                55397766781          True
# 28027                    9778066                55983293990          True
# 28028                   16206666                48923952650          True
#
#        nftfi_liquidated    nftfi_loan_repaid_time  \
# 0                  True 2020-05-16 11:50:26+00:00
# 1                  True 2022-03-30 10:27:49+00:00
# 2                  True 2020-05-16 12:20:16+00:00
# 3                  True 2022-03-30 10:36:56+00:00
# 4                  True 2020-05-16 12:28:51+00:00
# ...                 ...                       ...
# 28024              True                       NaT
# 28025              True                       NaT
# 28026              True                       NaT
# 28027              True                       NaT
# 28028              True                       NaT
#
#       nftfi_repaid_amount_paid_to_lender  \
# 0                       3095000000000000
# 1                      10036100000000000
# 2                      30095000000000000
# 3                      10036100000000000
# 4                       3009500000000000
# ...                                  ...
# 28024                                NaN
# 28025                                NaN
# 28026                                NaN
# 28027                                NaN
# 28028                                NaN
#
#                            nftfi_repaid_transaction_hash  \
# 0      0x59d1c26160b7bdde716b380364b506e056d852ac1b36...
# 1      0xed765e1584d0588c100167ea8614e54681ac7b525fb0...
# 2      0xfa036df32071d8b4f301b34aa2893bc0499db7e79bf1...
# 3      0x2d6415762da5c2fc90dcfd4a7f0c19e30c57b45ae480...
# 4      0x8f70de246186ae66da45404c856b9db431b26bfcbe7f...
# ...                                                  ...
# 28024                                                NaN
# 28025                                                NaN
# 28026                                                NaN
# 28027                                                NaN
# 28028                                                NaN
#
#        nftfi_repaid_gas_price  nftfi_repaid_gas_limit  nftfi_repaid_gas_used  \
# 0           16,974,493,487.00              500,000.00             122,603.00
# 1           28,938,564,954.00              471,039.00             249,468.00
# 2           13,200,000,144.00              500,000.00             132,834.00
# 3           30,247,267,592.00              398,226.00             210,634.00
# 4           13,100,000,072.00              500,000.00             122,603.00
# ...                       ...                     ...                    ...
# 28024                     NaN                     NaN                    NaN
# 28025                     NaN                     NaN                    NaN
# 28026                     NaN                     NaN                    NaN
# 28027                     NaN                     NaN                    NaN
# 28028                     NaN                     NaN                    NaN
#
#        nftfi_repaid_cumulative_gas_used  nftfi_repaid_effective_gas_price  \
# 0                          9,470,068.00                 16,974,493,487.00
# 1                          9,338,789.00                 28,938,564,954.00
# 2                          4,140,219.00                 13,200,000,144.00
# 3                         16,058,990.00                 30,247,267,592.00
# 4                          9,570,320.00                 13,100,000,072.00
# ...                                 ...                               ...
# 28024                               NaN                               NaN
# 28025                               NaN                               NaN
# 28026                               NaN                               NaN
# 28027                               NaN                               NaN
# 28028                               NaN                               NaN
#
#       nftfi_repaid_admin_fee nftfi_loan_liquidation_date  \
# 0              5000000000000                         NaN
# 1              1900000000000                         NaN
# 2              5000000000000                         NaN
# 3              1900000000000                         NaN
# 4               500000000000                         NaN
# ...                      ...                         ...
# 28024                    NaN                         NaN
# 28025                    NaN                         NaN
# 28026                    NaN                         NaN
# 28027                    NaN                         NaN
# 28028                    NaN                         NaN
#
#       nftfi_liquidated_transaction_hash  nftfi_liquidated_gas_price  \
# 0                                   NaN                         NaN
# 1                                   NaN                         NaN
# 2                                   NaN                         NaN
# 3                                   NaN                         NaN
# 4                                   NaN                         NaN
# ...                                 ...                         ...
# 28024                               NaN                         NaN
# 28025                               NaN                         NaN
# 28026                               NaN                         NaN
# 28027                               NaN                         NaN
# 28028                               NaN                         NaN
#
#        nftfi_liquidated_gas_limit  nftfi_liquidated_gas_used  \
# 0                             NaN                        NaN
# 1                             NaN                        NaN
# 2                             NaN                        NaN
# 3                             NaN                        NaN
# 4                             NaN                        NaN
# ...                           ...                        ...
# 28024                         NaN                        NaN
# 28025                         NaN                        NaN
# 28026                         NaN                        NaN
# 28027                         NaN                        NaN
# 28028                         NaN                        NaN
#
#        nftfi_liquidated_cumulative_gas_used  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 28024                                   NaN
# 28025                                   NaN
# 28026                                   NaN
# 28027                                   NaN
# 28028                                   NaN
#
#        nftfi_liquidated_effective_gas_price nftfi_loan_no_cleaned  nftfi_high  \
# 0                                       NaN                     1         NaN
# 1                                       NaN                     1    3,396.32
# 2                                       NaN                     2         NaN
# 3                                       NaN                     2    3,398.36
# 4                                       NaN                     3         NaN
# ...                                     ...                   ...         ...
# 28024                                   NaN                 33808    1,834.86
# 28025                                   NaN                 33809    1,838.06
# 28026                                   NaN                 33810    1,838.06
# 28027                                   NaN                 33824    1,832.78
# 28028                                   NaN                 33825    1,836.37
#
#        nftfi_eth_price  nftfi_usd_value nftfi_loan_erc20denomination_name  \
# 0                  NaN              NaN                              weth
# 1             3,394.93            33.95                              weth
# 2                  NaN              NaN                              weth
# 3             3,397.60            33.98                              weth
# 4                  NaN              NaN                              weth
# ...                ...              ...                               ...
# 28024         1,834.07         2,292.59                              weth
# 28025         1,834.08         2,200.90                              weth
# 28026         1,834.08         2,200.90                              weth
# 28027         1,832.01        12,824.07                              weth
# 28028         1,835.90        12,851.30                              weth
#
#        nftfi_loan_type                                mq_transaction_hash  \
# 0        v1.loan.fixed  0x166d57a868ae6c3e34c192546aedc243eda0c7ba6685...
# 1        v2.loan.fixed  0x166d57a868ae6c3e34c192546aedc243eda0c7ba6685...
# 2        v1.loan.fixed  0x9d783e3bbde1663ffa2dcc0bf5eabeccbe3f58475938...
# 3        v2.loan.fixed  0x9d783e3bbde1663ffa2dcc0bf5eabeccbe3f58475938...
# 4        v1.loan.fixed  0x7d7682a9827b44571da3bdc1f7342d9ad3c985e7aedb...
# ...                ...                                                ...
# 28024  v2-1.loan.fixed  0x2573d462a1e5bc8c7085f18a317dee42c6003e86e40b...
# 28025  v2-1.loan.fixed  0x182b91443edf0fdcdf9210e2792a1475d6c47f9e8175...
# 28026  v2-1.loan.fixed  0x97b46e05a3d4e573b0cd59df2657c5478081e6a4d12f...
# 28027  v2-1.loan.fixed  0x862834c19fc5e3255d85ee631d45b38c210055fb8aa8...
# 28028  v2-1.loan.fixed  0x0f94288dd02f42bb2a38bbacffb8c8d7afa8c7519f8d...
#
#                    mq_block_timestamp  mq_loan_id  \
# 0      2022-03-30 10:21:32.000000 UTC           1
# 1      2022-03-30 10:21:32.000000 UTC           1
# 2      2022-03-30 10:36:00.000000 UTC           2
# 3      2022-03-30 10:36:00.000000 UTC           2
# 4      2022-03-30 10:43:05.000000 UTC           3
# ...                               ...         ...
# 28024  2023-04-24 17:38:59.000000 UTC       33808
# 28025  2023-04-24 17:44:47.000000 UTC       33809
# 28026  2023-04-24 17:44:59.000000 UTC       33810
# 28027  2023-04-24 19:36:11.000000 UTC       33824
# 28028  2023-04-24 20:02:59.000000 UTC       33825
#
#                                     mq_to_address  \
# 0      0x3e3b47b5d433be4708a6bd524facd48bb54d10b1
# 1      0x3e3b47b5d433be4708a6bd524facd48bb54d10b1
# 2      0x3e3b47b5d433be4708a6bd524facd48bb54d10b1
# 3      0x3e3b47b5d433be4708a6bd524facd48bb54d10b1
# 4      0x3e3b47b5d433be4708a6bd524facd48bb54d10b1
# ...                                           ...
# 28024  0xb2a2a6a69e7a0ad66943f4c2869d45a9919cf740
# 28025  0xb2a2a6a69e7a0ad66943f4c2869d45a9919cf740
# 28026  0xb2a2a6a69e7a0ad66943f4c2869d45a9919cf740
# 28027  0x353d1af0fa732f6230ff4ab0eb2a6a3dcf4c54f2
# 28028  0xd758bf1da4b9683454b97988175aa6f9419c2b39
#
#                                   mq_from_address  mq_principal_amount  \
# 0      0xd79275564ccad8e679cbbb5e1c2facd46643a372                 0.01
# 1      0xd79275564ccad8e679cbbb5e1c2facd46643a372                 0.01
# 2      0xd79275564ccad8e679cbbb5e1c2facd46643a372                 0.01
# 3      0xd79275564ccad8e679cbbb5e1c2facd46643a372                 0.01
# 4      0xd79275564ccad8e679cbbb5e1c2facd46643a372                 0.01
# ...                                           ...                  ...
# 28024  0xf4fb9fa23edb32215e5284cf7dbfdb5607d51a5b                 1.25
# 28025  0xf4fb9fa23edb32215e5284cf7dbfdb5607d51a5b                 1.20
# 28026  0xf4fb9fa23edb32215e5284cf7dbfdb5607d51a5b                 1.20
# 28027  0x1797b4235473fbe0e7e44322f01c1b5618ebda41                 7.00
# 28028  0x1797b4235473fbe0e7e44322f01c1b5618ebda41                 7.00
#
#        mq_repayment_amount                            mq_erc20_address  \
# 0                     0.01  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1                     0.01  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 2                     0.01  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 3                     0.01  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 4                     0.01  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# ...                    ...                                         ...
# 28024                 1.33  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28025                 1.28  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28026                 1.28  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28027                 7.63  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 28028                 7.63  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
#
#       mq_erc20_name                     mq_due_date  mq_duration_in_days  \
# 0              wETH  2022-04-13 10:21:32.000000 UTC                14.00
# 1              wETH  2022-04-13 10:21:32.000000 UTC                14.00
# 2              wETH  2022-04-13 10:36:00.000000 UTC                14.00
# 3              wETH  2022-04-13 10:36:00.000000 UTC                14.00
# 4              wETH  2022-03-30 10:50:17.000000 UTC                 0.01
# ...             ...                             ...                  ...
# 28024          wETH  2023-06-23 17:38:59.000000 UTC                60.00
# 28025          wETH  2023-06-23 17:44:47.000000 UTC                60.00
# 28026          wETH  2023-06-23 17:44:59.000000 UTC                60.00
# 28027          wETH  2024-04-23 19:36:11.000000 UTC               365.00
# 28028          wETH  2024-04-23 20:02:59.000000 UTC               365.00
#
#        mq_apr mq_token_id                       mq_collection_address  \
# 0        0.10     1000323  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a
# 1        0.10     1000323  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a
# 2        0.10      735355  0x06012c8cf97bead5deae237070f9587f8e7a266d
# 3        0.10      735355  0x06012c8cf97bead5deae237070f9587f8e7a266d
# 4        0.73     1000323  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a
# ...       ...         ...                                         ...
# 28024    0.39        2496  0x42069abfe407c60cf4ae4112bedead391dba1cdb
# 28025    0.39        1044  0x42069abfe407c60cf4ae4112bedead391dba1cdb
# 28026    0.39        4770  0x42069abfe407c60cf4ae4112bedead391dba1cdb
# 28027    0.09        3903  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a
# 28028    0.09         795  0x059edd72cd353df5106d2b9cc5ab83a52287ac3a
#
#       mq_protocol  mq_amt_in_usd  mq_roll_over  mq_block_number mq_p2p_p2pool  \
# 0           nftfi          33.89         False         14487024           p2p
# 1           nftfi          33.89         False         14487024           p2p
# 2           nftfi          33.89         False         14487091           p2p
# 3           nftfi          33.89         False         14487091           p2p
# 4           nftfi          33.89         False         14487122           p2p
# ...           ...            ...           ...              ...           ...
# 28024       nftfi       2,267.92         False         17117683           p2p
# 28025       nftfi       2,177.20         False         17117712           p2p
# 28026       nftfi       2,177.20         False         17117713           p2p
# 28027       nftfi      12,820.53         False         17118262           p2p
# 28028       nftfi      12,818.90         False         17118392           p2p
#
#       mq_loan_id_cleaned
# 0                      1
# 1                      1
# 2                      2
# 3                      2
# 4                      3
# ...                  ...
# 28024              33808
# 28025              33809
# 28026              33810
# 28027              33824
# 28028              33825
#
# [28029 rows x 64 columns]

# %%
subset_of_matching_mq_with_nftfi = matching_mq_with_nftfi[['nftfi_date', 'mq_block_timestamp', 'nftfi_usd_value', 'mq_amt_in_usd', 'nftfi_loan_no_cleaned', 'nftfi_loan_type', 'mq_loan_id_cleaned']]
subset_of_matching_mq_with_nftfi
# Out:
#                      nftfi_date              mq_block_timestamp  \
# 0     2020-05-16 10:05:07+00:00  2022-03-30 10:21:32.000000 UTC
# 1     2022-03-30 10:21:32+00:00  2022-03-30 10:21:32.000000 UTC
# 2     2020-05-16 11:30:55+00:00  2022-03-30 10:36:00.000000 UTC
# 3     2022-03-30 10:36:00+00:00  2022-03-30 10:36:00.000000 UTC
# 4     2020-05-16 12:25:35+00:00  2022-03-30 10:43:05.000000 UTC
# ...                         ...                             ...
# 28024 2023-04-24 17:38:59+00:00  2023-04-24 17:38:59.000000 UTC
# 28025 2023-04-24 17:44:47+00:00  2023-04-24 17:44:47.000000 UTC
# 28026 2023-04-24 17:44:59+00:00  2023-04-24 17:44:59.000000 UTC
# 28027 2023-04-24 19:36:11+00:00  2023-04-24 19:36:11.000000 UTC
# 28028 2023-04-24 20:02:59+00:00  2023-04-24 20:02:59.000000 UTC
#
#        nftfi_usd_value  mq_amt_in_usd nftfi_loan_no_cleaned  nftfi_loan_type  \
# 0                  NaN          33.89                     1    v1.loan.fixed
# 1                33.95          33.89                     1    v2.loan.fixed
# 2                  NaN          33.89                     2    v1.loan.fixed
# 3                33.98          33.89                     2    v2.loan.fixed
# 4                  NaN          33.89                     3    v1.loan.fixed
# ...                ...            ...                   ...              ...
# 28024         2,292.59       2,267.92                 33808  v2-1.loan.fixed
# 28025         2,200.90       2,177.20                 33809  v2-1.loan.fixed
# 28026         2,200.90       2,177.20                 33810  v2-1.loan.fixed
# 28027        12,824.07      12,820.53                 33824  v2-1.loan.fixed
# 28028        12,851.30      12,818.90                 33825  v2-1.loan.fixed
#
#       mq_loan_id_cleaned
# 0                      1
# 1                      1
# 2                      2
# 3                      2
# 4                      3
# ...                  ...
# 28024              33808
# 28025              33809
# 28026              33810
# 28027              33824
# 28028              33825
#
# [28029 rows x 7 columns]

# %%
pd.options.plotting.backend = "plotly"
subset_of_matching_mq_with_nftfi['dollar_diff'] = subset_of_matching_mq_with_nftfi['nftfi_usd_value'] - subset_of_matching_mq_with_nftfi['mq_amt_in_usd']

subset_of_matching_mq_with_nftfi.nftfi_date = pd.to_datetime(subset_of_matching_mq_with_nftfi.nftfi_date)
subset_of_matching_mq_with_nftfi.mq_block_timestamp = pd.to_datetime(subset_of_matching_mq_with_nftfi.mq_block_timestamp)

subset_of_matching_mq_with_nftfi.plot.scatter(x=subset_of_matching_mq_with_nftfi.nftfi_date, y=subset_of_matching_mq_with_nftfi.dollar_diff)
# Out:
# /tmp/ipykernel_3199236/2272234492.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_of_matching_mq_with_nftfi['dollar_diff'] = subset_of_matching_mq_with_nftfi['nftfi_usd_value'] - subset_of_matching_mq_with_nftfi['mq_amt_in_usd']
# /tmp/ipykernel_3199236/2272234492.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_of_matching_mq_with_nftfi.nftfi_date = pd.to_datetime(subset_of_matching_mq_with_nftfi.nftfi_date)
# /tmp/ipykernel_3199236/2272234492.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset_of_matching_mq_with_nftfi.mq_block_timestamp = pd.to_datetime(subset_of_matching_mq_with_nftfi.mq_block_timestamp)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/PycharmProjects/ChartGPT/venv/lib/python3.10/site-packages/IPython/core/formatters.py:922, in IPythonDisplayFormatter.__call__(self, obj)
#     920 method = get_real_method(obj, self.print_method)
#     921 if method is not None:
# --> 922     method()
#     923     return True
#
# File ~/PycharmProjects/ChartGPT/venv/lib/python3.10/site-packages/plotly/basedatatypes.py:834, in BaseFigure._ipython_display_(self)
#     831 import plotly.io as pio
#     833 if pio.renderers.render_on_display and pio.renderers.default:
# --> 834     pio.show(self)
#     835 else:
#     836     print(repr(self))
#
# File ~/PycharmProjects/ChartGPT/venv/lib/python3.10/site-packages/plotly/io/_renderers.py:396, in show(fig, renderer, validate, **kwargs)
#     391         raise ValueError(
#     392             "Mime type rendering requires ipython but it is not installed"
#     393         )
#     395     if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 396         raise ValueError(
#     397             "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     398         )
#     400     ipython_display.display(bundle, raw=True)
#     402 # external renderers
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
# Figure({
#     'data': [{'hovertemplate': 'nftfi_date=%{x}<br>dollar_diff=%{y}<extra></extra>',
#               'legendgroup': '',
#               'marker': {'color': '#636efa', 'symbol': 'circle'},
#               'mode': 'markers',
#               'name': '',
#               'showlegend': False,
#               'type': 'scattergl',
#               'x': array([datetime.datetime(2020, 5, 16, 10, 5, 7, tzinfo=<UTC>),
#                           datetime.datetime(2022, 3, 30, 10, 21, 32, tzinfo=<UTC>),
#                           datetime.datetime(2020, 5, 16, 11, 30, 55, tzinfo=<UTC>), ...,
#                           datetime.datetime(2023, 4, 24, 17, 44, 59, tzinfo=<UTC>),
#                           datetime.datetime(2023, 4, 24, 19, 36, 11, tzinfo=<UTC>),
#                           datetime.datetime(2023, 4, 24, 20, 2, 59, tzinfo=<UTC>)], dtype=object),
#               'xaxis': 'x',
#               'y': array([      nan,  0.061058,       nan, ..., 23.69508 ,  3.535   , 32.3967  ]),
#               'yaxis': 'y'}],
#     'layout': {'legend': {'tracegroupgap': 0},
#                'margin': {'t': 60},
#                'template': '...',
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'title': {'text': 'nftfi_date'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.0, 1.0], 'title': {'text': 'dollar_diff'}}}
# })

# %%
subset_of_matching_mq_with_nftfi['date_diff'] = subset_of_matching_mq_with_nftfi['nftfi_date'] - subset_of_matching_mq_with_nftfi['mq_block_timestamp']
subset_of_matching_mq_with_nftfi.plot.scatter(x=subset_of_matching_mq_with_nftfi.nftfi_date, y=subset_of_matching_mq_with_nftfi.date_diff)

# %%
import numpy as np
subset_of_matching_mq_with_nftfi['date_diff'] = subset_of_matching_mq_with_nftfi['nftfi_date'] - subset_of_matching_mq_with_nftfi['mq_block_timestamp']
non_zero_time_delta = subset_of_matching_mq_with_nftfi.loc[subset_of_matching_mq_with_nftfi['date_diff'] > np.timedelta64(0)]
display(non_zero_time_delta)
display(non_zero_time_delta.nftfi_loan_type.unique())

print(f"min, max nftfi [{non_zero_time_delta.nftfi_date.min(), non_zero_time_delta.nftfi_date.max()}]")
print(f"min, max mq [{non_zero_time_delta.mq_block_timestamp.min(), non_zero_time_delta.mq_block_timestamp.max()}]")

print(f"\n\nTotal dollar diff for non zero time deltas (IDs not matching) [{non_zero_time_delta.dollar_diff.sum()}]")
print(f"Total dollar diff for both datasets [{subset_of_matching_mq_with_nftfi.dollar_diff.sum()}]")

# %%
nftfi.date = pd.to_datetime(nftfi.date)
time_delta = pd.Timedelta(minutes=20)
datemax_minus_time_delta = non_zero_time_delta.nftfi_date.max() - time_delta
datemax_plus_time_delta = non_zero_time_delta.nftfi_date.max() + time_delta

print(non_zero_time_delta.nftfi_date.max())
nftfi.loc[nftfi.date < datemax_plus_time_delta].loc[datemax_minus_time_delta < nftfi.date].sort_values('date')

# %%
non_zero_time_delta.loc[non_zero_time_delta['dollar_diff'] == 0]

# %% [markdown]
# ### Are missing loans from MQ relative to NFTfi, bundles?

# %%
display(unique_to_april_nftfi.collection_name.unique())
len(unique_to_april_nftfi.collection_name.unique())

# %%
display(unique_to_april_mq.collection_address.unique()[:3])
len(unique_to_april_mq.collection_address.unique())

# %% [markdown]
# ## How are liquidations accounted for?

# %%
# TODO:
# spreadsheet of different transactions that are missing, or are more of them on MQ dataset. we need clear doc discussing which tsx are missing, which are added,
# what are the volume differences coming from.

# try and check that the eth value of those loans per transaction is the same.
# check if volumes per loanerc20 collateral are matching

# %% [markdown]
# ## Sandbox

# %%
try: 
    volume = pd.read_csv('analysis/nftfi_cluster_data/3month_200apr_with_borrow_volume.csv')
    base_data = pd.read_csv('analysis/nftfi_cluster_data/20230522_CADLabs_NFTfi NFT collection APR ranges_vDraft - past 3M; loan count 20; APRs 200; 5 clusters.csv')
except FileNotFoundError:
    volume = (
        pd.read_csv('nftfi_cluster_data/3month_200apr_with_borrow_volume.csv')
        .drop(columns=['mean', 'median', 'std', 'count'])
    )
    base_data = (
        pd.read_csv('nftfi_cluster_data/20230522_CADLabs_NFTfi NFT collection APR ranges_vDraft - past 3M; loan count 20; APRs 200; 5 clusters.csv')
        .drop(columns=['Unnamed: 0', 'Unnamed: 7', 'Unnamed: 8'])
    )

# %%
display(volume.head(2))
display(base_data.head(2))

# %%
nftfi = pd.merge(left=base_data, right=volume, on='collection_name')
nftfi 
# list(nftfi['borrow_volume'].values)
